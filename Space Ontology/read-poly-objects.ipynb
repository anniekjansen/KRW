# %%
import geopandas as gpd
import pandas as pd
import rdflib
from rdflib import Graph, Literal, Namespace, RDF, RDFS, URIRef, OWL, BNode
from rdflib.namespace import DC, FOAF
import pprint

# %%
gdf = gpd.read_file('./data/vu-square.shp')

# %%
gdf
# Out:
#     ID     Object     Type        Name  \
# 0    1       Tree     None       Tree1
# 1    2       Tree     None       Tree2
# 2    3       Tree     None       Tree3
# 3    1     Stairs     None     Stairs1
# 4    4       Tree     None       Tree4
# 5    1       Tent     None       Tent1
# 6    2       Tent     None       Tent2
# 7    1       Pole     None       Pole1
# 8    2       Pole     None       Pole2
# 9    1   Trashbin    Glass   Trashbin1
# 10   2   Trashbin    Paper   Trashbin2
# 11   3   Trashbin  General   Trashbin3
# 12   4   Trashbin  Organic   Trashbin4
# 13   5   Trashbin  Plastic   Trashbin5
# 14   1  LostFound     None  LostFound1
# 15   6   Trashbin  Plastic   Trashbin6
# 16   7   Trashbin  General   Trashbin7
# 17   8   Trashbin    Paper   Trashbin8
# 18   9   Trashbin  Organic   Trashbin9
# 19  10   Trashbin    Glass  Trashbin10
# 20   1      Beach     None      Beach1
# 21   8      Table     None      Table8
# 22   9      Table     None      Table9
# 23  10      Table     None     Table10
# 24  11      Table     None     Table11
# 25   7      Table     None      Table7
# 26   6      Table     None      Table6
# 27   5      Table     None      Table5
# 28   4      Table     None      Table4
# 29   3      Table     None      Table3
# 30   2      Table     None      Table2
# 31   1      Table     None      Table1
# 32   1     Square     None     Square1
#
#                                              geometry
# 0   POLYGON ((4.86502 52.33367, 4.86505 52.33367, ...
# 1   POLYGON ((4.86510 52.33373, 4.86513 52.33373, ...
# 2   POLYGON ((4.86515 52.33407, 4.86524 52.33407, ...
# 3   POLYGON ((4.86571 52.33431, 4.86576 52.33431, ...
# 4   POLYGON ((4.86573 52.33388, 4.86575 52.33388, ...
# 5   POLYGON ((4.86550 52.33428, 4.86564 52.33424, ...
# 6   POLYGON ((4.86538 52.33413, 4.86553 52.33409, ...
# 7   POLYGON ((4.86552 52.33401, 4.86555 52.33400, ...
# 8   POLYGON ((4.86537 52.33377, 4.86536 52.33376, ...
# 9   POLYGON ((4.86581 52.33362, 4.86584 52.33362, ...
# 10  POLYGON ((4.86485 52.33364, 4.86487 52.33364, ...
# 11  POLYGON ((4.86516 52.33393, 4.86518 52.33393, ...
# 12  POLYGON ((4.86531 52.33422, 4.86533 52.33422, ...
# 13  POLYGON ((4.86562 52.33408, 4.86564 52.33408, ...
# 14  POLYGON ((4.86511 52.33423, 4.86515 52.33423, ...
# 15  POLYGON ((4.86490 52.33374, 4.86492 52.33374, ...
# 16  POLYGON ((4.86589 52.33393, 4.86592 52.33393, ...
# 17  POLYGON ((4.86565 52.33430, 4.86567 52.33430, ...
# 18  POLYGON ((4.86521 52.33369, 4.86523 52.33369, ...
# 19  POLYGON ((4.86561 52.33393, 4.86563 52.33392, ...
# 20  POLYGON ((4.86471 52.33407, 4.86502 52.33407, ...
# 21  POLYGON ((4.86500 52.33362, 4.86503 52.33362, ...
# 22  POLYGON ((4.86505 52.33362, 4.86509 52.33362, ...
# 23  POLYGON ((4.86510 52.33362, 4.86514 52.33362, ...
# 24  POLYGON ((4.86515 52.33364, 4.86518 52.33364, ...
# 25  POLYGON ((4.86521 52.33360, 4.86521 52.33362, ...
# 26  POLYGON ((4.86526 52.33360, 4.86526 52.33362, ...
# 27  POLYGON ((4.86531 52.33360, 4.86531 52.33362, ...
# 28  POLYGON ((4.86536 52.33360, 4.86536 52.33362, ...
# 29  POLYGON ((4.86541 52.33360, 4.86541 52.33362, ...
# 30  POLYGON ((4.86546 52.33362, 4.86549 52.33362, ...
# 31  POLYGON ((4.86552 52.33362, 4.86554 52.33362, ...
# 32  POLYGON ((4.86594 52.33351, 4.86471 52.33350, ...

# %% [markdown]
# ## Shapefile manipulation - if needed

# %%
def set_name(t, name):
    if t is not None:
        return t + name
    else:
        return name

# %%
def set_class(obj):
    if obj == "Square":
        return obj
    elif obj.endswith("Trashbin"):
        return obj
    else:
        return "Obstacle"

# %%
def set_type(t, obj):
    if obj.endswith("Trashbin"):
        return t
    else:
        return obj

# %%
gdf['Object'] = gdf.apply(lambda x: set_name(x.Type, x.Object), axis=1)
gdf
# Out:
#     ID           Object     Type        Name  \
# 0    1             Tree     None       Tree1
# 1    2             Tree     None       Tree2
# 2    3             Tree     None       Tree3
# 3    1           Stairs     None     Stairs1
# 4    4             Tree     None       Tree4
# 5    1             Tent     None       Tent1
# 6    2             Tent     None       Tent2
# 7    1             Pole     None       Pole1
# 8    2             Pole     None       Pole2
# 9    1    GlassTrashbin    Glass   Trashbin1
# 10   2    PaperTrashbin    Paper   Trashbin2
# 11   3  GeneralTrashbin  General   Trashbin3
# 12   4  OrganicTrashbin  Organic   Trashbin4
# 13   5  PlasticTrashbin  Plastic   Trashbin5
# 14   1        LostFound     None  LostFound1
# 15   6  PlasticTrashbin  Plastic   Trashbin6
# 16   7  GeneralTrashbin  General   Trashbin7
# 17   8    PaperTrashbin    Paper   Trashbin8
# 18   9  OrganicTrashbin  Organic   Trashbin9
# 19  10    GlassTrashbin    Glass  Trashbin10
# 20   1            Beach     None      Beach1
# 21   8            Table     None      Table8
# 22   9            Table     None      Table9
# 23  10            Table     None     Table10
# 24  11            Table     None     Table11
# 25   7            Table     None      Table7
# 26   6            Table     None      Table6
# 27   5            Table     None      Table5
# 28   4            Table     None      Table4
# 29   3            Table     None      Table3
# 30   2            Table     None      Table2
# 31   1            Table     None      Table1
# 32   1           Square     None     Square1
#
#                                              geometry
# 0   POLYGON ((4.86502 52.33367, 4.86505 52.33367, ...
# 1   POLYGON ((4.86510 52.33373, 4.86513 52.33373, ...
# 2   POLYGON ((4.86515 52.33407, 4.86524 52.33407, ...
# 3   POLYGON ((4.86571 52.33431, 4.86576 52.33431, ...
# 4   POLYGON ((4.86573 52.33388, 4.86575 52.33388, ...
# 5   POLYGON ((4.86550 52.33428, 4.86564 52.33424, ...
# 6   POLYGON ((4.86538 52.33413, 4.86553 52.33409, ...
# 7   POLYGON ((4.86552 52.33401, 4.86555 52.33400, ...
# 8   POLYGON ((4.86537 52.33377, 4.86536 52.33376, ...
# 9   POLYGON ((4.86581 52.33362, 4.86584 52.33362, ...
# 10  POLYGON ((4.86485 52.33364, 4.86487 52.33364, ...
# 11  POLYGON ((4.86516 52.33393, 4.86518 52.33393, ...
# 12  POLYGON ((4.86531 52.33422, 4.86533 52.33422, ...
# 13  POLYGON ((4.86562 52.33408, 4.86564 52.33408, ...
# 14  POLYGON ((4.86511 52.33423, 4.86515 52.33423, ...
# 15  POLYGON ((4.86490 52.33374, 4.86492 52.33374, ...
# 16  POLYGON ((4.86589 52.33393, 4.86592 52.33393, ...
# 17  POLYGON ((4.86565 52.33430, 4.86567 52.33430, ...
# 18  POLYGON ((4.86521 52.33369, 4.86523 52.33369, ...
# 19  POLYGON ((4.86561 52.33393, 4.86563 52.33392, ...
# 20  POLYGON ((4.86471 52.33407, 4.86502 52.33407, ...
# 21  POLYGON ((4.86500 52.33362, 4.86503 52.33362, ...
# 22  POLYGON ((4.86505 52.33362, 4.86509 52.33362, ...
# 23  POLYGON ((4.86510 52.33362, 4.86514 52.33362, ...
# 24  POLYGON ((4.86515 52.33364, 4.86518 52.33364, ...
# 25  POLYGON ((4.86521 52.33360, 4.86521 52.33362, ...
# 26  POLYGON ((4.86526 52.33360, 4.86526 52.33362, ...
# 27  POLYGON ((4.86531 52.33360, 4.86531 52.33362, ...
# 28  POLYGON ((4.86536 52.33360, 4.86536 52.33362, ...
# 29  POLYGON ((4.86541 52.33360, 4.86541 52.33362, ...
# 30  POLYGON ((4.86546 52.33362, 4.86549 52.33362, ...
# 31  POLYGON ((4.86552 52.33362, 4.86554 52.33362, ...
# 32  POLYGON ((4.86594 52.33351, 4.86471 52.33350, ...

# %%
gdf['Class'] = gdf.apply(lambda x: set_class(x.Object), axis=1)

# %%
gdf['Type'] = gdf.apply(lambda x: set_type(x.Type, x.Object), axis=1)

# %%
gdf = gdf.drop(columns=['Object'])
gdf
# Out:
#     ID       Type        Name  \
# 0    1       Tree       Tree1
# 1    2       Tree       Tree2
# 2    3       Tree       Tree3
# 3    1     Stairs     Stairs1
# 4    4       Tree       Tree4
# 5    1       Tent       Tent1
# 6    2       Tent       Tent2
# 7    1       Pole       Pole1
# 8    2       Pole       Pole2
# 9    1      Glass   Trashbin1
# 10   2      Paper   Trashbin2
# 11   3    General   Trashbin3
# 12   4    Organic   Trashbin4
# 13   5    Plastic   Trashbin5
# 14   1  LostFound  LostFound1
# 15   6    Plastic   Trashbin6
# 16   7    General   Trashbin7
# 17   8      Paper   Trashbin8
# 18   9    Organic   Trashbin9
# 19  10      Glass  Trashbin10
# 20   1      Beach      Beach1
# 21   8      Table      Table8
# 22   9      Table      Table9
# 23  10      Table     Table10
# 24  11      Table     Table11
# 25   7      Table      Table7
# 26   6      Table      Table6
# 27   5      Table      Table5
# 28   4      Table      Table4
# 29   3      Table      Table3
# 30   2      Table      Table2
# 31   1      Table      Table1
# 32   1     Square     Square1
#
#                                              geometry            Class
# 0   POLYGON ((4.86502 52.33367, 4.86505 52.33367, ...         Obstacle
# 1   POLYGON ((4.86510 52.33373, 4.86513 52.33373, ...         Obstacle
# 2   POLYGON ((4.86515 52.33407, 4.86524 52.33407, ...         Obstacle
# 3   POLYGON ((4.86571 52.33431, 4.86576 52.33431, ...         Obstacle
# 4   POLYGON ((4.86573 52.33388, 4.86575 52.33388, ...         Obstacle
# 5   POLYGON ((4.86550 52.33428, 4.86564 52.33424, ...         Obstacle
# 6   POLYGON ((4.86538 52.33413, 4.86553 52.33409, ...         Obstacle
# 7   POLYGON ((4.86552 52.33401, 4.86555 52.33400, ...         Obstacle
# 8   POLYGON ((4.86537 52.33377, 4.86536 52.33376, ...         Obstacle
# 9   POLYGON ((4.86581 52.33362, 4.86584 52.33362, ...    GlassTrashbin
# 10  POLYGON ((4.86485 52.33364, 4.86487 52.33364, ...    PaperTrashbin
# 11  POLYGON ((4.86516 52.33393, 4.86518 52.33393, ...  GeneralTrashbin
# 12  POLYGON ((4.86531 52.33422, 4.86533 52.33422, ...  OrganicTrashbin
# 13  POLYGON ((4.86562 52.33408, 4.86564 52.33408, ...  PlasticTrashbin
# 14  POLYGON ((4.86511 52.33423, 4.86515 52.33423, ...         Obstacle
# 15  POLYGON ((4.86490 52.33374, 4.86492 52.33374, ...  PlasticTrashbin
# 16  POLYGON ((4.86589 52.33393, 4.86592 52.33393, ...  GeneralTrashbin
# 17  POLYGON ((4.86565 52.33430, 4.86567 52.33430, ...    PaperTrashbin
# 18  POLYGON ((4.86521 52.33369, 4.86523 52.33369, ...  OrganicTrashbin
# 19  POLYGON ((4.86561 52.33393, 4.86563 52.33392, ...    GlassTrashbin
# 20  POLYGON ((4.86471 52.33407, 4.86502 52.33407, ...         Obstacle
# 21  POLYGON ((4.86500 52.33362, 4.86503 52.33362, ...         Obstacle
# 22  POLYGON ((4.86505 52.33362, 4.86509 52.33362, ...         Obstacle
# 23  POLYGON ((4.86510 52.33362, 4.86514 52.33362, ...         Obstacle
# 24  POLYGON ((4.86515 52.33364, 4.86518 52.33364, ...         Obstacle
# 25  POLYGON ((4.86521 52.33360, 4.86521 52.33362, ...         Obstacle
# 26  POLYGON ((4.86526 52.33360, 4.86526 52.33362, ...         Obstacle
# 27  POLYGON ((4.86531 52.33360, 4.86531 52.33362, ...         Obstacle
# 28  POLYGON ((4.86536 52.33360, 4.86536 52.33362, ...         Obstacle
# 29  POLYGON ((4.86541 52.33360, 4.86541 52.33362, ...         Obstacle
# 30  POLYGON ((4.86546 52.33362, 4.86549 52.33362, ...         Obstacle
# 31  POLYGON ((4.86552 52.33362, 4.86554 52.33362, ...         Obstacle
# 32  POLYGON ((4.86594 52.33351, 4.86471 52.33350, ...           Square

# %% [markdown]
# # Add centroids

# %%
gdf['centroid'] = gdf.centroid
# Out:
# C:\Users\Kris\AppData\Local\Temp/ipykernel_11012/390209964.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['centroid'] = gdf.centroid

# %%
gdf
# Out:
#     ID       Type        Name  \
# 0    1       Tree       Tree1
# 1    2       Tree       Tree2
# 2    3       Tree       Tree3
# 3    1     Stairs     Stairs1
# 4    4       Tree       Tree4
# 5    1       Tent       Tent1
# 6    2       Tent       Tent2
# 7    1       Pole       Pole1
# 8    2       Pole       Pole2
# 9    1      Glass   Trashbin1
# 10   2      Paper   Trashbin2
# 11   3    General   Trashbin3
# 12   4    Organic   Trashbin4
# 13   5    Plastic   Trashbin5
# 14   1  LostFound  LostFound1
# 15   6    Plastic   Trashbin6
# 16   7    General   Trashbin7
# 17   8      Paper   Trashbin8
# 18   9    Organic   Trashbin9
# 19  10      Glass  Trashbin10
# 20   1      Beach      Beach1
# 21   8      Table      Table8
# 22   9      Table      Table9
# 23  10      Table     Table10
# 24  11      Table     Table11
# 25   7      Table      Table7
# 26   6      Table      Table6
# 27   5      Table      Table5
# 28   4      Table      Table4
# 29   3      Table      Table3
# 30   2      Table      Table2
# 31   1      Table      Table1
# 32   1     Square     Square1
#
#                                              geometry            Class  \
# 0   POLYGON ((4.86502 52.33367, 4.86505 52.33367, ...         Obstacle
# 1   POLYGON ((4.86510 52.33373, 4.86513 52.33373, ...         Obstacle
# 2   POLYGON ((4.86515 52.33407, 4.86524 52.33407, ...         Obstacle
# 3   POLYGON ((4.86571 52.33431, 4.86576 52.33431, ...         Obstacle
# 4   POLYGON ((4.86573 52.33388, 4.86575 52.33388, ...         Obstacle
# 5   POLYGON ((4.86550 52.33428, 4.86564 52.33424, ...         Obstacle
# 6   POLYGON ((4.86538 52.33413, 4.86553 52.33409, ...         Obstacle
# 7   POLYGON ((4.86552 52.33401, 4.86555 52.33400, ...         Obstacle
# 8   POLYGON ((4.86537 52.33377, 4.86536 52.33376, ...         Obstacle
# 9   POLYGON ((4.86581 52.33362, 4.86584 52.33362, ...    GlassTrashbin
# 10  POLYGON ((4.86485 52.33364, 4.86487 52.33364, ...    PaperTrashbin
# 11  POLYGON ((4.86516 52.33393, 4.86518 52.33393, ...  GeneralTrashbin
# 12  POLYGON ((4.86531 52.33422, 4.86533 52.33422, ...  OrganicTrashbin
# 13  POLYGON ((4.86562 52.33408, 4.86564 52.33408, ...  PlasticTrashbin
# 14  POLYGON ((4.86511 52.33423, 4.86515 52.33423, ...         Obstacle
# 15  POLYGON ((4.86490 52.33374, 4.86492 52.33374, ...  PlasticTrashbin
# 16  POLYGON ((4.86589 52.33393, 4.86592 52.33393, ...  GeneralTrashbin
# 17  POLYGON ((4.86565 52.33430, 4.86567 52.33430, ...    PaperTrashbin
# 18  POLYGON ((4.86521 52.33369, 4.86523 52.33369, ...  OrganicTrashbin
# 19  POLYGON ((4.86561 52.33393, 4.86563 52.33392, ...    GlassTrashbin
# 20  POLYGON ((4.86471 52.33407, 4.86502 52.33407, ...         Obstacle
# 21  POLYGON ((4.86500 52.33362, 4.86503 52.33362, ...         Obstacle
# 22  POLYGON ((4.86505 52.33362, 4.86509 52.33362, ...         Obstacle
# 23  POLYGON ((4.86510 52.33362, 4.86514 52.33362, ...         Obstacle
# 24  POLYGON ((4.86515 52.33364, 4.86518 52.33364, ...         Obstacle
# 25  POLYGON ((4.86521 52.33360, 4.86521 52.33362, ...         Obstacle
# 26  POLYGON ((4.86526 52.33360, 4.86526 52.33362, ...         Obstacle
# 27  POLYGON ((4.86531 52.33360, 4.86531 52.33362, ...         Obstacle
# 28  POLYGON ((4.86536 52.33360, 4.86536 52.33362, ...         Obstacle
# 29  POLYGON ((4.86541 52.33360, 4.86541 52.33362, ...         Obstacle
# 30  POLYGON ((4.86546 52.33362, 4.86549 52.33362, ...         Obstacle
# 31  POLYGON ((4.86552 52.33362, 4.86554 52.33362, ...         Obstacle
# 32  POLYGON ((4.86594 52.33351, 4.86471 52.33350, ...           Square
#
#                     centroid
# 0   POINT (4.86503 52.33366)
# 1   POINT (4.86512 52.33373)
# 2   POINT (4.86519 52.33404)
# 3   POINT (4.86574 52.33416)
# 4   POINT (4.86574 52.33388)
# 5   POINT (4.86552 52.33419)
# 6   POINT (4.86543 52.33408)
# 7   POINT (4.86553 52.33400)
# 8   POINT (4.86536 52.33377)
# 9   POINT (4.86582 52.33361)
# 10  POINT (4.86486 52.33363)
# 11  POINT (4.86517 52.33393)
# 12  POINT (4.86532 52.33422)
# 13  POINT (4.86563 52.33408)
# 14  POINT (4.86513 52.33421)
# 15  POINT (4.86491 52.33373)
# 16  POINT (4.86591 52.33392)
# 17  POINT (4.86566 52.33429)
# 18  POINT (4.86522 52.33369)
# 19  POINT (4.86561 52.33392)
# 20  POINT (4.86487 52.33391)
# 21  POINT (4.86502 52.33361)
# 22  POINT (4.86507 52.33361)
# 23  POINT (4.86512 52.33361)
# 24  POINT (4.86517 52.33362)
# 25  POINT (4.86523 52.33361)
# 26  POINT (4.86528 52.33361)
# 27  POINT (4.86533 52.33361)
# 28  POINT (4.86538 52.33361)
# 29  POINT (4.86543 52.33362)
# 30  POINT (4.86548 52.33361)
# 31  POINT (4.86553 52.33361)
# 32  POINT (4.86536 52.33388)

# %% [markdown]
# ## Load existing KG

# %%
g = Graph()

g.parse("./data/final_ontology.ttl", format='ttl')

pprint.pprint(g.serialize(format="ttl"))
# Out:
# ('@prefix TRASH: <http://www.trashrobot.com/onto/> .\n'
#  '@prefix geof: <http://www.opengis.net/def/function/geosparql/> .\n'
#  '@prefix geos: <http://www.opengis.net/ont/geosparql#> .\n'
#  '@prefix ns1: <http://knowrob.org/kb/knowrob.owl#> .\n'
#  '@prefix owl: <http://www.w3.org/2002/07/owl#> .\n'
#  '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\n'
#  '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n'
#  '@prefix skos: <http://www.w3.org/2004/02/skos/core#> .\n'
#  '@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Air_freshener> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Airfreshener .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Aluminium_foil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Aluminumfoil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Antacid> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Antacid .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Apple> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Apples .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Apple_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Applesauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Asparagus> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Asparagus .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Aspirin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Aspirin .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Automotive_battery> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:AutomativeBatteries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Avocado> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Avocados .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bacon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bacon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bagel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bagels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Baked_beans> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bakedbeans .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Baking_powder> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bakingpowder .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ballpoint_pen> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pen .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Banana> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bananas .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Band-Aid> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Band-aids .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Barbecue_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:BBQsauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Basil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Basil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Beef> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Beef .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Beer> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Beer .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bell_pepper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Peppers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Berry> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Berries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bin_bag> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Garbagebags .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Black_pepper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Blackpepper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Blue_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bleucheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bolognese_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pastasauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bouillon_cube> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bouilloncubes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bourbon_whiskey> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Whiskey .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bread> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ready-bakebreads .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bread_crumbs> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Breadcrumbs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Breakfast_cereal> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cereal .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Broccoli> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Broccoli .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Burrito> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Burritos .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Butter> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Butter .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cake> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cake .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Candy> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Candy/Gum> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Canned_tomato> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tomatoes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Carrot> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Carrots .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Catfish> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Catfish .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cauliflower> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cauliflower .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Celery> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Celery .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Charcoal> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Charcoal .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cheddar_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cheddar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cherry> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cherries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chicken> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chicken .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chili_con_carne> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chili .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chips_and_dip> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chipdip .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chocolate_chip> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Chocolatechips/Cocoa> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cinnamon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cinnamon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Coffee> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Coffee .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cookie> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cookies .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cooking_spray> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Non-stickspray .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Coriander> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cilantro .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cottage_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cottagecheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cotton_swab> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cottonswabs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Crab> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Crab .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cream_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Creamcheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Croissant> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Croissants .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Crushed_red_pepper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Redpepper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cucumber> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cucumbers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/DVD> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:DVD .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Dental_floss> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Floss .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Deodorant> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Deodorant .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Detergent> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Detergent .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Dishwasher_detergent> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Dishwashersoap .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Doughnut> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Donuts .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Dried_fruit> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Driedfruit .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Edible_mushroom> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mushrooms .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Egg_as_food> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Eggs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/English_muffin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Englishmuffins .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Envelope> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Envelope .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Feta> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Feta .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Fish_finger> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Fishsticks .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Flour> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Flour .\n'
#  '\n'
#  '<http://dbpedia.org/resource/French_fries> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Fries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Frozen_vegetables> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vegetables .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Garlic> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Garlic .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Gin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Gin .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ginger> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ginger .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Goat_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Goatcheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Graham_cracker> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Crackers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Granola> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Granolabar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Grape> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Grapes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Grapefruit> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Grapefruit .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Gravy> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Gravy .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ground_beef> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Groundbeef .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hair_gel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hairgel .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ham> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ham .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Honey> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Honey .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hot_dog> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hotdogs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hot_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hotsauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hummus> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hummus .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ice_cream> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Icecream .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ice_pop> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Popsicles .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Incandescent_light_bulb> a owl:NamedIndividual '
#  ';\n'
#  '    owl:sameAs TRASH:Lightbulbs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Insect_repellent> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Insectrepellent .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Instant_mashed_potatoes> a owl:NamedIndividual '
#  ';\n'
#  '    owl:sameAs TRASH:Instantmashedpotatoes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Juice> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Fruitjuice,\n'
#  '        TRASH:Juice .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ketchup> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ketchup .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Kiwi> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Kiwis .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lemon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Lemons .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lettuce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Lettuce/Greens> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lime_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Limes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lip_balm> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Lipbalm .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lobster> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Lobster .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Macaroni_and_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Mac&cheese> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Magazine> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Magazine .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mayonnaise> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mayonnaise .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Melon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Melon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Milk> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Milk .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mint> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mint .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mozzarella> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mozzarella .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mussel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mussels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mustard_(condiment)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mustard .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Napkin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Napkins .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Newspaper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Newspaper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Notebook> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Notebook .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Nut_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Nuts .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Oatmeal> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oatmeal .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Olive> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Olives .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Olive_oil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oliveoil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Onion> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Onions .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Orange_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oranges .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Oregano> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oregano .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Oyster> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oysters .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pancake> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pancakes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Paper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Printerpaper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Paper_towel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Papertowels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Paprika> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Paprika .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Parmigiano-Reggiano> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Parmesan .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Parsley> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Parsley .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pasta> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pasta .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Peach_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Peaches .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Peach_(fruit))> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Nectarines .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Peanut_butter> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Peanutbutter .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pear> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pears .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pencil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pencil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pickles> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pickles .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pita> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pitabread .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pizza> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pizza .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Plastic_wrap> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Plasticwrap .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Plum> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Plums .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Popcorn> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Popcorn .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Postage_stamp> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Postagestamps .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Potato> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Potatoes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Potato_chip> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chips .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pretzel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pretzels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Propane> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Propane .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Relish> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Relish .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Rice> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Rice .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ricotta> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ricotta .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Rum> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Rum .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Salmon_as_food> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Salmon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Salsa_(sauce)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Salsa .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Salt> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Salt .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sandwich> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sandwichslices .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sausage> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sausage .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Shampoo> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Shampoo/Conditioner> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Shrimp> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Shrimp .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sliced_bread> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Slicedbread .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soap> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Handsoap .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soft_drink> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Softdrink .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soup> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Soups .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sour_cream> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sourcream .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soy_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Soysauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Spam_(food)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Spam .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Spinach> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Spinach .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sponge> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sponge .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sports_drink> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sportsdrink .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Steak_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Steaksauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Stitch_and_glue> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Glue .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sugar> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sugar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sunscreen> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Shampoo .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sweet_corn> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Corn .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Swiss_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Swiss .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Syrup> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Syrup .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tea> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tea .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tilapia> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tilapia .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tofu> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tofu .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Toilet_paper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Toiletpaper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tomato> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Tomatoes*> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tonic_water> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tonic .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Toothpaste> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Toothpaste .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tortilla> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tortillas .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tuna> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tuna,\n'
#  '        <http://www.trashrobot.com/onto/Tuna/Chicken> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Turkey_as_food> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Turkey .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vanilla_extract> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vanillaextract .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vegetable_oil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vegetableoil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Veggie_burger> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Veggieburgers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vinegar> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vinegar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vodka> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vodka .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Whipped_cream> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Whippedcream .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Wine> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Wine .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Worcestershire_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Worcestershiresauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Yeast> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Yeast .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Yogurt> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Yogurt .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Zucchini> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Zucchini .\n'
#  '\n'
#  '<http://knowrob.org/kb/actions.owl#Mapping> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Perceiving> .\n'
#  '\n'
#  'ns1:AvoidLookingAt a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:OrientationConstraint .\n'
#  '\n'
#  'ns1:B21 a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:BottleCap a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedComponent> '
#  '.\n'
#  '\n'
#  'ns1:Candle a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#DesignedSubstance> .\n'
#  '\n'
#  'ns1:CeilingLight a owl:Class ;\n'
#  '    rdfs:comment "The collection of all ceiling lights." ;\n'
#  '    rdfs:subClassOf ns1:LightFixture .\n'
#  '\n'
#  'ns1:CenterOfObject a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DependentPlace> .\n'
#  '\n'
#  'ns1:Chopping a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Cutting .\n'
#  '\n'
#  'ns1:Cleaning a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#ModifyingPhysicalObject> .\n'
#  '\n'
#  'ns1:Cloth a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TextileArtifact .\n'
#  '\n'
#  'ns1:Cooling a owl:Class ;\n'
#  '    rdfs:comment "A specialization of TemperatureChangingProcess. Each '
#  'instance of CoolingProcess is an event in which the temperature of some '
#  'object (related to the instance of CoolingProcess by objectOfStateChange) is '
#  'lowered."^^xsd:string ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#ProcessType> .\n'
#  '\n'
#  'ns1:ElectricLamp a owl:Class ;\n'
#  '    rdfs:comment "The collection for all kinds of freestanding (easily '
#  'moveable) electrical lamps." ;\n'
#  '    rdfs:subClassOf ns1:LightFixture .\n'
#  '\n'
#  'ns1:ElectricalOutlet a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:ElectricalPlug a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:FaultyHardware a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:InoperableHardware .\n'
#  '\n'
#  'ns1:FinishBefore a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TemporalConstraint .\n'
#  '\n'
#  'ns1:Flashlight a owl:Class ;\n'
#  '    rdfs:comment "A small portable electric lamp powered by batteries." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#DesignedTool> .\n'
#  '\n'
#  'ns1:FlatScreenMonitor a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Monitor .\n'
#  '\n'
#  'ns1:Flipping a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Actuating> .\n'
#  '\n'
#  'ns1:Heating a owl:Class ;\n'
#  '    rdfs:comment "A specialization of TemperatureChangingProcess. During '
#  'each HeatingProcess event, the temperature of the objectOfStateChange is '
#  'increased by applying heat to the object. Any instance of '
#  'IntrinsicStateChangeEvent in which an object temperature is increased is '
#  'also an instance of this collection."^^xsd:string ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#ProcessType> .\n'
#  '\n'
#  'ns1:Hook a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Connector .\n'
#  '\n'
#  'ns1:Image a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#InformationObject> .\n'
#  '\n'
#  'ns1:IncompleteModel a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:IndexFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:IndicatorLight a owl:Class ;\n'
#  '    rdfs:comment "The collection of all indicator lights." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice .\n'
#  '\n'
#  'ns1:InvalidArgument a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:KBQueryingExecution a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#ActionExecutionPlan> .\n'
#  '\n'
#  'ns1:KeepAbove a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepAtAngle a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:OrientationConstraint .\n'
#  '\n'
#  'ns1:KeepAwayFrom a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:DistanceConstraint .\n'
#  '\n'
#  'ns1:KeepBehind a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepBelow a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepCloseTo a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:DistanceConstraint .\n'
#  '\n'
#  'ns1:KeepInfront a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepLeftOf a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepLookingAt a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:OrientationConstraint .\n'
#  '\n'
#  'ns1:KeepRightOf a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepStill a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:LocationConstraint .\n'
#  '\n'
#  'ns1:KeepUpright a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepPerpendicularTo .\n'
#  '\n'
#  'ns1:Knedding a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Mixing> .\n'
#  '\n'
#  'ns1:Lamp-Hanging a owl:Class ;\n'
#  '    rdfs:comment "The collection of all hanging lamps." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice .\n'
#  '\n'
#  'ns1:LeftArm a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Arm> ;\n'
#  '    owl:disjointWith ns1:RightArm .\n'
#  '\n'
#  'ns1:LeftHand a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Hand> ;\n'
#  '    owl:disjointWith ns1:RightHand .\n'
#  '\n'
#  'ns1:LeftLeg a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Leg> ;\n'
#  '    owl:disjointWith ns1:RightLeg .\n'
#  '\n'
#  'ns1:Lightbulb a owl:Class ;\n'
#  '    rdfs:comment "A bulb of glass or quartz enclosing material that '
#  'incandesces or fluoresces when provided with current, thus generating '
#  'light." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:LittleFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:MapFrame a owl:NamedIndividual .\n'
#  '\n'
#  'ns1:MiddleFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:MissingArgument a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:MobileBase a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Appliance> .\n'
#  '\n'
#  'ns1:MoveCarefully a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:LocationConstraint .\n'
#  '\n'
#  'ns1:NonRechargeableBattery a owl:Class ;\n'
#  '    rdfs:comment "Batteries which may not be recharged (cf. '
#  'ChargingABattery)." ;\n'
#  '    rdfs:subClassOf ns1:Battery .\n'
#  '\n'
#  'ns1:ObjectMainAxis a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DependentPlace> .\n'
#  '\n'
#  'ns1:ObjectOverlooked a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FailedAttempt> .\n'
#  '\n'
#  'ns1:OperableHardware a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#HardwareDiagnosis> '
#  '.\n'
#  '\n'
#  'ns1:PR2 a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:ParameterInference a owl:Class ;\n'
#  '    rdfs:comment "A reasoning task where the value of a parameter is '
#  'determined." ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onClass '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> ;\n'
#  '            owl:onProperty ns1:hasInferredParameter ;\n'
#  '            owl:qualifiedCardinality "1"^^xsd:nonNegativeInteger ],\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#Reasoning> .\n'
#  '\n'
#  'ns1:Pin a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Connector .\n'
#  '\n'
#  'ns1:Pose_MapFrame a owl:NamedIndividual ;\n'
#  '    ns1:quaternion "0.0 0.0 0.0 1.0"^^xsd:string ;\n'
#  '    ns1:translation "0.0 0.0 0.0"^^xsd:string .\n'
#  '\n'
#  'ns1:PouringInto a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Pouring .\n'
#  '\n'
#  'ns1:PouringOnto a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Pouring .\n'
#  '\n'
#  'ns1:Proprioception a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Perception .\n'
#  '\n'
#  'ns1:Reasoner a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> .\n'
#  '\n'
#  'ns1:RechargeableBattery a owl:Class ;\n'
#  '    rdfs:comment "Batteries which may be recharged (cf. ChargingABattery)." '
#  ';\n'
#  '    rdfs:subClassOf ns1:Battery .\n'
#  '\n'
#  'ns1:ResourceMissing a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Infeasibility> .\n'
#  '\n'
#  'ns1:ResourceNotFound a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FailedAttempt> .\n'
#  '\n'
#  'ns1:RfidPerception a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Perception .\n'
#  '\n'
#  'ns1:RingFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:RobovieMR2 a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:SemanticEnvironmentMap a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Map .\n'
#  '\n'
#  'ns1:Serving a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Actuating> .\n'
#  '\n'
#  'ns1:Slicing a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Cutting .\n'
#  '\n'
#  'ns1:Stirring a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Mixing> .\n'
#  '\n'
#  'ns1:StreetLight a owl:Class ;\n'
#  '    rdfs:comment "The collection of all streetlights." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice .\n'
#  '\n'
#  'ns1:TUM_Rosie a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:Thumb a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:TouchPerception a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Perception .\n'
#  '\n'
#  'ns1:Towel a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TextileArtifact .\n'
#  '\n'
#  'ns1:UndefinedReference a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:Ungraspable a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Inability> .\n'
#  '\n'
#  'ns1:Unliftable a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Inability> .\n'
#  '\n'
#  'ns1:UnpoweredHardware a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:InoperableHardware .\n'
#  '\n'
#  'ns1:Unreachable a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Inability> .\n'
#  '\n'
#  'ns1:WaitUntil a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TemporalConstraint .\n'
#  '\n'
#  'ns1:WallMirror a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedFurniture> '
#  '.\n'
#  '\n'
#  'ns1:WasteBasket a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedFurniture> '
#  '.\n'
#  '\n'
#  'ns1:Water a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Fluid> .\n'
#  '\n'
#  'ns1:Wheel a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedComponent> '
#  '.\n'
#  '\n'
#  'ns1:areaOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:avoidedObject a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  'ns1:causedBy a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  'ns1:connectedTo-Rigidly a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:connectedTo .\n'
#  '\n'
#  'ns1:dangerousPart a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasPhysicalComponent> .\n'
#  '\n'
#  'ns1:depthOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasDepth> .\n'
#  '\n'
#  'ns1:describedInMap a owl:ObjectProperty ;\n'
#  '    rdfs:range ns1:Map ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#isPartOf> .\n'
#  '\n'
#  'ns1:detectedArtifact a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:detectedObject,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#involvesArtifact> .\n'
#  '\n'
#  'ns1:detectedPerson a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:detectedAgent .\n'
#  '\n'
#  'ns1:deviceUsed a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#involvesArtifact> .\n'
#  '\n'
#  'ns1:doorHingedTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:hingedTo .\n'
#  '\n'
#  'ns1:duration a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasEventTime> '
#  '.\n'
#  '\n'
#  'ns1:electricalPart a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasPhysicalComponent> .\n'
#  '\n'
#  'ns1:endTime a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasEventEnd> .\n'
#  '\n'
#  'ns1:firstName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:floorNumber a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:frameName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:fromLocation a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#involvesPlace> .\n'
#  '\n'
#  'ns1:fromState a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> .\n'
#  '\n'
#  'ns1:fullName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:goalLocation a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:eventOccursAt .\n'
#  '\n'
#  'ns1:hasAffordance a owl:AsymmetricProperty,\n'
#  '        owl:InverseFunctionalProperty,\n'
#  '        owl:IrreflexiveProperty,\n'
#  '        owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasQuality> .\n'
#  '\n'
#  'ns1:hasArity a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has arity" ;\n'
#  '    rdfs:range xsd:int ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:hasFirstProcedureArgument a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:hasProcedureArgument .\n'
#  '\n'
#  'ns1:hasFunctor a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has functor" ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:hasLifetime a owl:ObjectProperty .\n'
#  '\n'
#  'ns1:hasModulePath a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has module path" ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:hasPoseData a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has pose data" ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasLocalizationParameter> .\n'
#  '\n'
#  'ns1:hasResolution a owl:ObjectProperty ;\n'
#  '    rdfs:label "has resolution" ;\n'
#  '    rdfs:domain '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#PhysicalObject> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> .\n'
#  '\n'
#  'ns1:hasSamplingRate a owl:ObjectProperty ;\n'
#  '    rdfs:label "has sampling rate" ;\n'
#  '    rdfs:domain ns1:SensorDevice ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> .\n'
#  '\n'
#  'ns1:hasSensorRange a owl:ObjectProperty ;\n'
#  '    rdfs:label "has sensor range" ;\n'
#  '    rdfs:domain ns1:SensorDevice ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> .\n'
#  '\n'
#  'ns1:hasVisual a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:boolean ;\n'
#  '    rdfs:subPropertyOf ns1:visualHint .\n'
#  '\n'
#  'ns1:hasXScale a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:hasYScale a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:hasZScale a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:heightOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasHeight> .\n'
#  '\n'
#  'ns1:inFieldOfView a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:inReachOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:inputsDestroyed a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:inputsRemaining a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:isAboveOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> ;\n'
#  '    owl:inverseOf ns1:isBelowOf .\n'
#  '\n'
#  'ns1:isBehindOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> ;\n'
#  '    owl:inverseOf ns1:isInFrontOf .\n'
#  '\n'
#  'ns1:isInCenterOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:isInsideOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:isLeftOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:isNextTo ;\n'
#  '    owl:inverseOf ns1:isRightOf .\n'
#  '\n'
#  'ns1:isOntopOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:lastName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:lightConeAngle a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "The opening angle of spot lights. Must be below or equal '
#  'pi/2. Default is pi/3." ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightDirection a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "determines orientation of spot lights." ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightDistance a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "determines light attenuation. I guess threejs interprets '
#  'this as \\"the light shines lightDistance meters\\" (or so)" ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightExponent a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "Used as exponent in spot effect computation: '
#  'effect=x^exponent. Exponents below 1 make light brighter, above darker. '
#  'Default value is 10. Only meaningful for spotlights." ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightIntensity a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "numeric value of the light\'s strength/intensity. Default '
#  'is 1." ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightTarget a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> .\n'
#  '\n'
#  'ns1:lightType a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "One of \'spot\', \'point\', or \'directional\'. '
#  'Corresponds to different light types used in Computer Graphics." ;\n'
#  '    rdfs:range [ a rdfs:Datatype ;\n'
#  '            owl:oneOf [ a rdf:List ;\n'
#  '                    rdf:first "directional" ;\n'
#  '                    rdf:rest [ a rdf:List ;\n'
#  '                            rdf:first "point" ;\n'
#  '                            rdf:rest [ a rdf:List ;\n'
#  '                                    rdf:first "spot" ;\n'
#  '                                    rdf:rest () ] ] ] ] ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:linkToImageFile a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:mainColorOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range <http://www.ease-crc.org/ont/SOMA.owl#array_double> ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasRGBValue> .\n'
#  '\n'
#  'ns1:maxJointValue a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf ns1:jointLimitParameters .\n'
#  '\n'
#  'ns1:minJointValue a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf ns1:jointLimitParameters .\n'
#  '\n'
#  'ns1:near a owl:ObjectProperty ;\n'
#  '    rdfs:comment "This intentionally-vague predicate relates spatial things '
#  'that are relatively near each other. (near THIS THAT) means that the '
#  'distance between THIS and THAT is such that -- given the situation at hand '
#  'and the sorts of things that THIS and THAT are -- they would be considered '
#  'near each other by most observers. Note that an object is near itself, '
#  'anything it touches, and any part of itself. When appropriate, use a more '
#  'precisely-defined predicate such as nearToDegree, nearRelativeTo, '
#  'nearForRolesInEventType, nearnessForRolesInEventType, touches_Directly, or '
#  'physicalParts."^^xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:numberOfLevels a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:positiveInteger ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:numberOfStories a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:positiveInteger ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:objectID a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:int ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:objectOfStateChange a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:objectRemoved a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:objectTransported a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:outputsCreated a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:postActor .\n'
#  '\n'
#  'ns1:pathToCadModel a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasFilePath> .\n'
#  '\n'
#  'ns1:performedInMap a owl:ObjectProperty ;\n'
#  '    rdfs:range ns1:Map ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  'ns1:prismaticallyConnectedTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:connectedTo .\n'
#  '\n'
#  'ns1:processStarted a owl:ObjectProperty ;\n'
#  '    rdfs:domain '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Event> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasConstituent> .\n'
#  '\n'
#  'ns1:processStopped a owl:ObjectProperty ;\n'
#  '    rdfs:domain '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Event> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasConstituent> .\n'
#  '\n'
#  'ns1:quaternion a owl:DatatypeProperty ;\n'
#  '    rdfs:range <http://www.ease-crc.org/ont/SOMA.owl#array_double> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasOrientationVector> .\n'
#  '\n'
#  'ns1:relativeTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> .\n'
#  '\n'
#  'ns1:roomNumber a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:scale a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:startTime a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasEventBegin> '
#  '.\n'
#  '\n'
#  'ns1:storedAtPlace a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:streetNumber a owl:DatatypeProperty,\n'
#  '        owl:FunctionalProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:temperatureOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  'ns1:thermicallyConnectedTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:connectedTo .\n'
#  '\n'
#  'ns1:toLocation a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor,\n'
# ...
#  '\n'
#  'ns1:detectedObject a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:postActor .\n'
#  '\n'
#  'ns1:eventOccursAt a owl:ObjectProperty ;\n'
#  '    rdfs:comment """An ActorSlot and a specialization of inRegion that '
#  'relates a particular event to the instance of EnduringThing_Localized at '
#  'which it occurs. (eventOccursAt EVENT LOC) means that the spatial extent of '
#  'EVENT is within LOC. For example, (eventOccursAt LomaPrietaEarthquake '
#  'SanFranciscoBayArea).\\r\n'
#  '\\r\n'
#  'See also the more general predicate eventPartiallyOccursAt, which relates an '
#  'event to any instance of SpatialThing_Localized in which some sub-event of '
#  'it occurs.""" ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:isNextTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:jointLimitParameters a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  'ns1:postActor a owl:ObjectProperty ;\n'
#  '    rdfs:range owl:Thing ;\n'
#  '    rdfs:subPropertyOf ns1:actor .\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#TopologicalMap> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Arm> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#DependentPlace> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#DesignedFurniture> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#ExitOGPWorkflow> a owl:Class ;\n'
#  '    rdfs:comment """A final Task in a OGPWorkflow, which is simply to return '
#  'some information as a "result" of the workflow\'s execution.\\r\n'
#  '\\r\n'
#  'This task only uses outputs. The values for the outputs are calculated by '
#  'the KnowRob workflow interpreter based on the Bindings between roles that '
#  'exist in the workflow.""" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onClass '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Entity> ;\n'
#  '            owl:onProperty '
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesOutput> ;\n'
#  '            owl:qualifiedCardinality "0"^^xsd:nonNegativeInteger ],\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#OGPTask> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#FailedAttempt> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Hand> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#HardwareDiagnosis> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Leg> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Mixing> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#ProcessType> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Reasoning> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesInput> a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesOutput> a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasPhysicalComponent> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#involvesArtifact> a owl:ObjectProperty '
#  '.\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#involvesPlace> a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Entity> a owl:Class '
#  '.\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#InformationEntity> a '
#  'owl:Class .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasConstituent> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  'geos:SpatialObject a owl:Class ;\n'
#  '    rdfs:label "SpatialObject" ;\n'
#  '    rdfs:subClassOf owl:Thing .\n'
#  '\n'
#  'geos:sfContains a owl:ObjectProperty ;\n'
#  '    rdfs:label "sfContains" .\n'
#  '\n'
#  'geos:wktLiteral a rdfs:Datatype ;\n'
#  '    rdfs:label "wktLiteral" .\n'
#  '\n'
#  'TRASH:ArmMovement a owl:Class ;\n'
#  '    rdfs:subClassOf TRASH:StandingAction .\n'
#  '\n'
#  'TRASH:GeneralTrashBin a owl:Class ;\n'
#  '    rdfs:label "GeneralTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:GlassTrashBin a owl:Class ;\n'
#  '    rdfs:label "GlassTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:LivingCreature a owl:Class ;\n'
#  '    rdfs:label "LivingCreature" ;\n'
#  '    rdfs:subClassOf TRASH:NonTrashObject .\n'
#  '\n'
#  'TRASH:LostAndFound a owl:Class ;\n'
#  '    rdfs:label "LostAndFound" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:bringTo ;\n'
#  '            owl:someValuesFrom TRASH:LostFound ],\n'
#  '        TRASH:NonTrashObject .\n'
#  '\n'
#  'TRASH:MovableObject a owl:Class ;\n'
#  '    rdfs:label "MovableObject" ;\n'
#  '    rdfs:subClassOf TRASH:Object .\n'
#  '\n'
#  'TRASH:OrganicTrashBin a owl:Class ;\n'
#  '    rdfs:label "OrganicTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:PaperTrashBin a owl:Class ;\n'
#  '    rdfs:label "PaperTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:PlasticTrashBin a owl:Class ;\n'
#  '    rdfs:label "PlasticTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:StandingAction a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#PhysicalAction> .\n'
#  '\n'
#  'TRASH:Vehicle a owl:Class ;\n'
#  '    rdfs:label "Vehicle" ;\n'
#  '    rdfs:subClassOf TRASH:NonTrashObject .\n'
#  '\n'
#  'TRASH:grab a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf owl:topObjectProperty .\n'
#  '\n'
#  'TRASH:performs a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf owl:topObjectProperty .\n'
#  '\n'
#  'TRASH:release a owl:ObjectProperty .\n'
#  '\n'
#  'TRASH:uses a owl:ObjectProperty .\n'
#  '\n'
#  'ns1:LocationConstraint a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:SpatialConstraint .\n'
#  '\n'
#  'ns1:SpatialConstraint a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Constraint .\n'
#  '\n'
#  'ns1:trajectory-Complete a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:eventOccursAt .\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#MetricMap> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Actuating> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Appliance> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#DesignedComponent> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Inability> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#PhaseTransition> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#array_double> a rdfs:Datatype .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Event> a owl:Class .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#definesTask> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#isRelatedToConcept> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  'geos:Geometry a owl:Class ;\n'
#  '    rdfs:label "Geometry" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:asWKT ;\n'
#  '            owl:someValuesFrom geos:wktLiteral ],\n'
#  '        geos:SpatialObject .\n'
#  '\n'
#  'TRASH:NonTrashObject a owl:Class ;\n'
#  '    rdfs:label "NonTrashObject" ;\n'
#  '    rdfs:subClassOf TRASH:MovableObject .\n'
#  '\n'
#  'TRASH:Object a owl:Class ;\n'
#  '    rdfs:label "TraceableObject"^^xsd:string ;\n'
#  '    rdfs:subClassOf geos:SpatialObject .\n'
#  '\n'
#  'ns1:Map a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Place> .\n'
#  '\n'
#  'ns1:OrientationConstraint a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:SpatialConstraint .\n'
#  '\n'
#  'ns1:WheeledRobot a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/urdf.owl#Robot> .\n'
#  '\n'
#  'ns1:connectedTo a owl:ObjectProperty ;\n'
#  '    rdfs:comment "An instance of ConnectionPredicate. (connectedTo OBJ1 '
#  'OBJ2) means that OBJ1 and OBJ2 are (directly or indirectly) physically '
#  'connected in a way that allows at most only limited types of relative motion '
#  'between them. A hinged connection, for example, allows limited rotational '
#  'motion between OBJ1 and OBJ2. In many cases, being connectedTo implicitly '
#  'involves another object(s); e.g. a door is connectedTo a door frame by a '
#  'hinge, which is itself connectedTo_Directly (q.v.) both the door and the '
#  'frame."^^xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:nameString a owl:DatatypeProperty ;\n'
#  '    rdfs:domain owl:Thing ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasNameString> '
#  '.\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#MapBuiltFromSensorData> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#OGPTask> a owl:Class ;\n'
#  '    rdfs:comment """A Task to be interpreted by the KnowRob Workflow '
#  'interpreter.\\r\n'
#  '\\r\n'
#  'Usually, has a non-empty set of input (Role or Parameter)s, and a non-empty '
#  'set of output (Role or Parameter)s-- however, eiter or both of these sets '
#  'may be empty in the case of tasks with trivial input/outputs.""" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:allValuesFrom [ a owl:Class ;\n'
#  '                    owl:unionOf ( '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> ) ] ;\n'
#  '            owl:onProperty '
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesInput> ],\n'
#  '        [ a owl:Restriction ;\n'
#  '            owl:allValuesFrom [ a owl:Class ;\n'
#  '                    owl:unionOf ( '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> ) ] ;\n'
#  '            owl:onProperty '
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesOutput> ],\n'
#  '        <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Task> .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> a owl:Class .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> a '
#  'owl:DatatypeProperty .\n'
#  '\n'
#  'TRASH:Material a owl:Class ;\n'
#  '    rdfs:label "Material" ;\n'
#  '    rdfs:subClassOf TRASH:TrashObject .\n'
#  '\n'
#  'TRASH:MovingAction a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#PhysicalAction> .\n'
#  '\n'
#  'TRASH:RecyclableMaterial a owl:Class ;\n'
#  '    rdfs:label "RecyclableMaterial" ;\n'
#  '    rdfs:subClassOf TRASH:Material .\n'
#  '\n'
#  'TRASH:StaticObject a owl:Class ;\n'
#  '    rdfs:label "StaticObject" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:hasGeometry ;\n'
#  '            owl:someValuesFrom geos:Geometry ],\n'
#  '        TRASH:Object .\n'
#  '\n'
#  'ns1:ElectricalLightingDevice a owl:Class ;\n'
#  '    rdfs:comment "Devices that provide light by transforming electrical '
#  'current into light energy." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:Finger a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#PhysicalEffector> '
#  '.\n'
#  '\n'
#  'ns1:Perception a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#MentalAction> .\n'
#  '\n'
#  'ns1:buildingParameter a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  'ns1:objectActedOn a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Concept> a owl:Class '
#  '.\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> a '
#  'owl:Class .\n'
#  '\n'
#  'TRASH:TrashObject a owl:Class ;\n'
#  '    rdfs:label "TrashObject" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:madeOf ;\n'
#  '            owl:someValuesFrom TRASH:Material ],\n'
#  '        [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putInto ;\n'
#  '            owl:someValuesFrom TRASH:TrashBin ],\n'
#  '        TRASH:MovableObject .\n'
#  '\n'
#  'ns1:ElectricalDevice a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Appliance> .\n'
#  '\n'
#  'ns1:KeepRelativeLocation a owl:Class ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty ns1:dependsOnConcept ;\n'
#  '            owl:someValuesFrom '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> ],\n'
#  '        ns1:LocationConstraint .\n'
#  '\n'
#  'ns1:lightParameter a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Map .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> a '
#  'owl:DatatypeProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> a '
#  'owl:DatatypeProperty .\n'
#  '\n'
#  'ns1:preActor a owl:ObjectProperty ;\n'
#  '    rdfs:comment "An ActorSlot (q.v.) that relates an event to those of its '
#  'participants that pre-exist it. (preActors EVENT OBJECT) means that OBJECT '
#  'is a participant (see actors) in EVENT and that OBJECT exists before EVENT '
#  'begins. Note that OBJECT also exists during at least part of EVENT (as '
#  'actors generalizes to temporallyIntersects). preActors is a very general '
#  'actor-slot, subsuming doneBy, objectActedOn, objectMoving, and many '
#  'others."^^xsd:string ;\n'
#  '    rdfs:range owl:Thing ;\n'
#  '    rdfs:subPropertyOf ns1:actor .\n'
#  '\n'
#  'TRASH:TrashBin a owl:Class ;\n'
#  '    rdfs:label "TrashBin" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:hasMetricVolume ;\n'
#  '            owl:someValuesFrom xsd:double ],\n'
#  '        TRASH:StaticObject .\n'
#  '\n'
#  'owl:topObjectProperty a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  'TRASH:GlassMaterial a owl:Class ;\n'
#  '    rdfs:label "GlassMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoGlassTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:GlassTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'TRASH:PaperMaterial a owl:Class ;\n'
#  '    rdfs:label "PaperMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoPaperTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:PaperTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'TRASH:PlasticMaterial a owl:Class ;\n'
#  '    rdfs:label "PlasticMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoPlasticTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:PlasticTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'TRASH:OrganicMaterial a owl:Class ;\n'
#  '    rdfs:label "OrganicMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoOrganicTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:OrganicTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'TRASH:OtherMaterial a owl:Class ;\n'
#  '    rdfs:label "OtherMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoGeneralTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:GeneralTrashBin ],\n'
#  '        TRASH:NonRecyclableMaterial .\n'
#  '\n')

# %%
TRASH = Namespace("http://www.trashrobot.com/onto/")
SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")
GEO = Namespace("http://www.opengis.net/ont/geosparql#")
SF = Namespace("http://www.opengis.net/ont/sf#")

# %%
g.namespace_manager.bind('TRASH', URIRef('http://www.trashrobot.com/onto/'))

# %%
# What are the classes of TRASH?
classes = []

for subjects in g.subjects(RDF.type, OWL.Class):
    if subjects.startswith(str(TRASH)):
        classes.append(subjects)
        
pprint.pprint(set(classes))
# Out:
# {rdflib.term.URIRef('http://www.trashrobot.com/onto/Animal'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/ArmMovement'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Bicycle'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Car'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/GeneralTrashBin'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/GlassMaterial'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/GlassTrashBin'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/HandMovement'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Human'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/LivingCreature'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/LostAndFound'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/LostFound'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Material'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/MoreBackward'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/MovableObject'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/MoveDown'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/MoveForward'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/MoveUp'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/MovingAction'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/NonRecyclableMaterial'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/NonTrashObject'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Object'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/ObjectRecognition'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Obstacle'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/OrganicMaterial'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/OrganicTrashBin'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/OtherMaterial'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/PaperMaterial'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/PaperTrashBin'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/PlasticMaterial'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/PlasticTrashBin'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/RecyclableMaterial'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Square'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/StandingAction'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/StaticObject'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/TrashBin'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/TrashObject'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/TurnLeft'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/TurnRight'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/Vehicle')}

# %%
# What are the classes of GEO?
classes = []

for subjects in g.subjects(RDF.type, OWL.Class):
    if subjects.startswith(str(GEO)):
        classes.append(subjects)
        
pprint.pprint(set(classes))
# Out:
# {rdflib.term.URIRef('http://www.opengis.net/ont/geosparql#Geometry'),
#  rdflib.term.URIRef('http://www.opengis.net/ont/geosparql#SpatialObject')}

# %%
# What are the properties?
props = []

for prop in g.predicates(None, None):
    #if subjects.startswith(str(GEO)):
    props.append(prop)
        
pprint.pprint(set(props))
# Out:
# {rdflib.term.URIRef('http://knowrob.org/kb/knowrob.owl#quaternion'),
#  rdflib.term.URIRef('http://knowrob.org/kb/knowrob.owl#translation'),
#  rdflib.term.URIRef('http://www.opengis.net/ont/geosparql#asWKT'),
#  rdflib.term.URIRef('http://www.opengis.net/ont/geosparql#hasGeometry'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#first'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#rest'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#domain'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subClassOf'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#allValuesFrom'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#disjointWith'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#imports'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#inverseOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#onClass'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#onProperty'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#oneOf'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#qualifiedCardinality'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#sameAs'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#someValuesFrom'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#unionOf'),
#  rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#definition')}

# %%
g.add((GEO.Feature, RDF.type, OWL.Class))
# Out:
# <Graph identifier=N3cd2ff639da647d0801c6f85e8b7dd71 (<class 'rdflib.graph.Graph'>)>

# %%
# Should Obstacle be a subclass of Feature like in the example or should we say it is equivalent class?

# %%
def test(row):
    ind_name = row.Name[0].lower() + row.Name[1:]
    geo_name = ind_name + "Geo"
    
    exec(f'g.add((TRASH.{ind_name}, RDF.type, OWL.NamedIndividual))')
    exec(f'g.add((TRASH.{ind_name}, RDF.type, TRASH.{row.Class}))')
    exec(f'g.add((TRASH.{ind_name}, RDFS.label, Literal("{ind_name}")))')
    
    exec(f'g.add((TRASH.{geo_name}, RDF.type, GEO.Geometry))')
    exec(f'g.add((TRASH.{geo_name}, RDFS.label, Literal("{geo_name}")))')
    exec(f'g.add((TRASH.{geo_name}, GEO.asWKT, Literal(\"{row.geometry}\", datatype=GEO.wktLiteral)))')
    
    exec(f'g.add((TRASH.{ind_name}, GEO.hasGeometry, TRASH.{geo_name}))')
    
    exec(f'centroid = BNode()')
    exec(f'g.add((centroid, RDF.type, GEO.Geometry))')
    exec(f'g.add((centroid, GEO.asWKT, Literal(\"{row.centroid}\", datatype=GEO.wktLiteral)))')
    
    exec(f'g.add((TRASH.{ind_name}, GEO.hasCentroid, centroid))')
    
gdf.apply(lambda x: test(x), axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# dtype: object

# %%
# What are the individuals of Geometry?
individuals = []

for subjects in g.subjects(RDF.type, GEO.Geometry):
    if subjects.startswith(str(TRASH)):
        individuals.append(subjects)
        
pprint.pprint(set(individuals))
# Out:
# {rdflib.term.URIRef('http://www.trashrobot.com/onto/beach1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/lostFound1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/pole1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/pole2Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/square1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/stairs1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table10Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table11Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table2Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table3Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table4Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table5Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table6Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table7Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table8Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/table9Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/tent1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/tent2Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin10Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin2Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin3Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin4Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin5Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin6Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin7Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin8Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/trashbin9Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/tree1Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/tree2Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/tree3Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/tree4Geo'),
#  rdflib.term.URIRef('http://www.trashrobot.com/onto/vuSquareGeo')}

# %%
g.remove((URIRef('http://www.trashrobot.com/onto/vuSquareGeo'), None, None))
g.remove((URIRef('http://www.trashrobot.com/onto/vuSquare'), None, None))
# Out:
# <Graph identifier=N3cd2ff639da647d0801c6f85e8b7dd71 (<class 'rdflib.graph.Graph'>)>

# %%
g.remove((None, None, URIRef('http://www.trashrobot.com/onto/vuSquareGeo')))
g.remove((None, None, URIRef('http://www.trashrobot.com/onto/vuSquare')))
# Out:
# <Graph identifier=N3cd2ff639da647d0801c6f85e8b7dd71 (<class 'rdflib.graph.Graph'>)>

# %%
pprint.pprint(g.serialize(format="ttl"))
# Out:
# ('@prefix TRASH: <http://www.trashrobot.com/onto/> .\n'
#  '@prefix geof: <http://www.opengis.net/def/function/geosparql/> .\n'
#  '@prefix geos: <http://www.opengis.net/ont/geosparql#> .\n'
#  '@prefix ns1: <http://knowrob.org/kb/knowrob.owl#> .\n'
#  '@prefix owl: <http://www.w3.org/2002/07/owl#> .\n'
#  '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .\n'
#  '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n'
#  '@prefix skos: <http://www.w3.org/2004/02/skos/core#> .\n'
#  '@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Air_freshener> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Airfreshener .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Aluminium_foil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Aluminumfoil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Antacid> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Antacid .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Apple> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Apples .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Apple_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Applesauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Asparagus> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Asparagus .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Aspirin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Aspirin .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Automotive_battery> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:AutomativeBatteries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Avocado> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Avocados .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bacon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bacon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bagel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bagels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Baked_beans> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bakedbeans .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Baking_powder> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bakingpowder .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ballpoint_pen> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pen .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Banana> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bananas .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Band-Aid> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Band-aids .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Barbecue_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:BBQsauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Basil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Basil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Beef> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Beef .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Beer> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Beer .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bell_pepper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Peppers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Berry> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Berries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bin_bag> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Garbagebags .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Black_pepper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Blackpepper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Blue_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bleucheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bolognese_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pastasauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bouillon_cube> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Bouilloncubes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bourbon_whiskey> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Whiskey .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bread> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ready-bakebreads .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Bread_crumbs> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Breadcrumbs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Breakfast_cereal> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cereal .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Broccoli> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Broccoli .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Burrito> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Burritos .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Butter> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Butter .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cake> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cake .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Candy> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Candy/Gum> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Canned_tomato> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tomatoes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Carrot> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Carrots .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Catfish> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Catfish .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cauliflower> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cauliflower .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Celery> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Celery .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Charcoal> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Charcoal .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cheddar_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cheddar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cherry> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cherries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chicken> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chicken .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chili_con_carne> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chili .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chips_and_dip> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chipdip .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Chocolate_chip> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Chocolatechips/Cocoa> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cinnamon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cinnamon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Coffee> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Coffee .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cookie> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cookies .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cooking_spray> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Non-stickspray .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Coriander> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cilantro .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cottage_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cottagecheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cotton_swab> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cottonswabs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Crab> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Crab .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cream_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Creamcheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Croissant> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Croissants .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Crushed_red_pepper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Redpepper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Cucumber> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Cucumbers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/DVD> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:DVD .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Dental_floss> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Floss .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Deodorant> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Deodorant .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Detergent> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Detergent .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Dishwasher_detergent> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Dishwashersoap .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Doughnut> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Donuts .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Dried_fruit> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Driedfruit .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Edible_mushroom> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mushrooms .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Egg_as_food> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Eggs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/English_muffin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Englishmuffins .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Envelope> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Envelope .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Feta> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Feta .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Fish_finger> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Fishsticks .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Flour> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Flour .\n'
#  '\n'
#  '<http://dbpedia.org/resource/French_fries> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Fries .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Frozen_vegetables> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vegetables .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Garlic> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Garlic .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Gin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Gin .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ginger> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ginger .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Goat_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Goatcheese .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Graham_cracker> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Crackers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Granola> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Granolabar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Grape> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Grapes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Grapefruit> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Grapefruit .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Gravy> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Gravy .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ground_beef> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Groundbeef .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hair_gel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hairgel .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ham> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ham .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Honey> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Honey .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hot_dog> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hotdogs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hot_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hotsauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Hummus> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Hummus .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ice_cream> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Icecream .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ice_pop> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Popsicles .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Incandescent_light_bulb> a owl:NamedIndividual '
#  ';\n'
#  '    owl:sameAs TRASH:Lightbulbs .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Insect_repellent> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Insectrepellent .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Instant_mashed_potatoes> a owl:NamedIndividual '
#  ';\n'
#  '    owl:sameAs TRASH:Instantmashedpotatoes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Juice> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Fruitjuice,\n'
#  '        TRASH:Juice .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ketchup> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ketchup .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Kiwi> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Kiwis .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lemon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Lemons .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lettuce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Lettuce/Greens> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lime_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Limes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lip_balm> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Lipbalm .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Lobster> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Lobster .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Macaroni_and_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Mac&cheese> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Magazine> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Magazine .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mayonnaise> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mayonnaise .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Melon> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Melon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Milk> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Milk .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mint> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mint .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mozzarella> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mozzarella .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mussel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mussels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Mustard_(condiment)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Mustard .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Napkin> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Napkins .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Newspaper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Newspaper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Notebook> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Notebook .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Nut_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Nuts .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Oatmeal> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oatmeal .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Olive> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Olives .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Olive_oil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oliveoil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Onion> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Onions .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Orange_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oranges .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Oregano> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oregano .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Oyster> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Oysters .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pancake> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pancakes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Paper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Printerpaper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Paper_towel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Papertowels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Paprika> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Paprika .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Parmigiano-Reggiano> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Parmesan .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Parsley> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Parsley .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pasta> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pasta .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Peach_(fruit)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Peaches .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Peach_(fruit))> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Nectarines .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Peanut_butter> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Peanutbutter .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pear> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pears .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pencil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pencil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pickles> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pickles .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pita> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pitabread .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pizza> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pizza .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Plastic_wrap> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Plasticwrap .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Plum> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Plums .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Popcorn> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Popcorn .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Postage_stamp> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Postagestamps .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Potato> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Potatoes .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Potato_chip> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Chips .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Pretzel> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Pretzels .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Propane> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Propane .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Relish> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Relish .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Rice> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Rice .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Ricotta> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Ricotta .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Rum> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Rum .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Salmon_as_food> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Salmon .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Salsa_(sauce)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Salsa .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Salt> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Salt .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sandwich> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sandwichslices .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sausage> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sausage .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Shampoo> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Shampoo/Conditioner> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Shrimp> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Shrimp .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sliced_bread> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Slicedbread .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soap> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Handsoap .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soft_drink> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Softdrink .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soup> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Soups .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sour_cream> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sourcream .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Soy_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Soysauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Spam_(food)> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Spam .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Spinach> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Spinach .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sponge> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sponge .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sports_drink> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sportsdrink .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Steak_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Steaksauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Stitch_and_glue> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Glue .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sugar> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Sugar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sunscreen> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Shampoo .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Sweet_corn> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Corn .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Swiss_cheese> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Swiss .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Syrup> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Syrup .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tea> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tea .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tilapia> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tilapia .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tofu> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tofu .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Toilet_paper> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Toiletpaper .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tomato> a owl:NamedIndividual ;\n'
#  '    owl:sameAs <http://www.trashrobot.com/onto/Tomatoes*> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tonic_water> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tonic .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Toothpaste> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Toothpaste .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tortilla> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tortillas .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Tuna> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Tuna,\n'
#  '        <http://www.trashrobot.com/onto/Tuna/Chicken> .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Turkey_as_food> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Turkey .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vanilla_extract> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vanillaextract .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vegetable_oil> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vegetableoil .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Veggie_burger> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Veggieburgers .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vinegar> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vinegar .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Vodka> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Vodka .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Whipped_cream> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Whippedcream .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Wine> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Wine .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Worcestershire_sauce> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Worcestershiresauce .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Yeast> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Yeast .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Yogurt> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Yogurt .\n'
#  '\n'
#  '<http://dbpedia.org/resource/Zucchini> a owl:NamedIndividual ;\n'
#  '    owl:sameAs TRASH:Zucchini .\n'
#  '\n'
#  '<http://knowrob.org/kb/actions.owl#Mapping> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Perceiving> .\n'
#  '\n'
#  'ns1:AvoidLookingAt a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:OrientationConstraint .\n'
#  '\n'
#  'ns1:B21 a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:BottleCap a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedComponent> '
#  '.\n'
#  '\n'
#  'ns1:Candle a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#DesignedSubstance> .\n'
#  '\n'
#  'ns1:CeilingLight a owl:Class ;\n'
#  '    rdfs:comment "The collection of all ceiling lights." ;\n'
#  '    rdfs:subClassOf ns1:LightFixture .\n'
#  '\n'
#  'ns1:CenterOfObject a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DependentPlace> .\n'
#  '\n'
#  'ns1:Chopping a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Cutting .\n'
#  '\n'
#  'ns1:Cleaning a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#ModifyingPhysicalObject> .\n'
#  '\n'
#  'ns1:Cloth a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TextileArtifact .\n'
#  '\n'
#  'ns1:Cooling a owl:Class ;\n'
#  '    rdfs:comment "A specialization of TemperatureChangingProcess. Each '
#  'instance of CoolingProcess is an event in which the temperature of some '
#  'object (related to the instance of CoolingProcess by objectOfStateChange) is '
#  'lowered."^^xsd:string ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#ProcessType> .\n'
#  '\n'
#  'ns1:ElectricLamp a owl:Class ;\n'
#  '    rdfs:comment "The collection for all kinds of freestanding (easily '
#  'moveable) electrical lamps." ;\n'
#  '    rdfs:subClassOf ns1:LightFixture .\n'
#  '\n'
#  'ns1:ElectricalOutlet a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:ElectricalPlug a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:FaultyHardware a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:InoperableHardware .\n'
#  '\n'
#  'ns1:FinishBefore a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TemporalConstraint .\n'
#  '\n'
#  'ns1:Flashlight a owl:Class ;\n'
#  '    rdfs:comment "A small portable electric lamp powered by batteries." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#DesignedTool> .\n'
#  '\n'
#  'ns1:FlatScreenMonitor a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Monitor .\n'
#  '\n'
#  'ns1:Flipping a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Actuating> .\n'
#  '\n'
#  'ns1:Heating a owl:Class ;\n'
#  '    rdfs:comment "A specialization of TemperatureChangingProcess. During '
#  'each HeatingProcess event, the temperature of the objectOfStateChange is '
#  'increased by applying heat to the object. Any instance of '
#  'IntrinsicStateChangeEvent in which an object temperature is increased is '
#  'also an instance of this collection."^^xsd:string ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#ProcessType> .\n'
#  '\n'
#  'ns1:Hook a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Connector .\n'
#  '\n'
#  'ns1:Image a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#InformationObject> .\n'
#  '\n'
#  'ns1:IncompleteModel a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:IndexFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:IndicatorLight a owl:Class ;\n'
#  '    rdfs:comment "The collection of all indicator lights." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice .\n'
#  '\n'
#  'ns1:InvalidArgument a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:KBQueryingExecution a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#ActionExecutionPlan> .\n'
#  '\n'
#  'ns1:KeepAbove a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepAtAngle a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:OrientationConstraint .\n'
#  '\n'
#  'ns1:KeepAwayFrom a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:DistanceConstraint .\n'
#  '\n'
#  'ns1:KeepBehind a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepBelow a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepCloseTo a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:DistanceConstraint .\n'
#  '\n'
#  'ns1:KeepInfront a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepLeftOf a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepLookingAt a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:OrientationConstraint .\n'
#  '\n'
#  'ns1:KeepRightOf a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepRelativeLocation .\n'
#  '\n'
#  'ns1:KeepStill a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:LocationConstraint .\n'
#  '\n'
#  'ns1:KeepUpright a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:KeepPerpendicularTo .\n'
#  '\n'
#  'ns1:Knedding a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Mixing> .\n'
#  '\n'
#  'ns1:Lamp-Hanging a owl:Class ;\n'
#  '    rdfs:comment "The collection of all hanging lamps." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice .\n'
#  '\n'
#  'ns1:LeftArm a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Arm> ;\n'
#  '    owl:disjointWith ns1:RightArm .\n'
#  '\n'
#  'ns1:LeftHand a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Hand> ;\n'
#  '    owl:disjointWith ns1:RightHand .\n'
#  '\n'
#  'ns1:LeftLeg a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Leg> ;\n'
#  '    owl:disjointWith ns1:RightLeg .\n'
#  '\n'
#  'ns1:Lightbulb a owl:Class ;\n'
#  '    rdfs:comment "A bulb of glass or quartz enclosing material that '
#  'incandesces or fluoresces when provided with current, thus generating '
#  'light." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:LittleFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:MapFrame a owl:NamedIndividual .\n'
#  '\n'
#  'ns1:MiddleFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:MissingArgument a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:MobileBase a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Appliance> .\n'
#  '\n'
#  'ns1:MoveCarefully a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:LocationConstraint .\n'
#  '\n'
#  'ns1:NonRechargeableBattery a owl:Class ;\n'
#  '    rdfs:comment "Batteries which may not be recharged (cf. '
#  'ChargingABattery)." ;\n'
#  '    rdfs:subClassOf ns1:Battery .\n'
#  '\n'
#  'ns1:ObjectMainAxis a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DependentPlace> .\n'
#  '\n'
#  'ns1:ObjectOverlooked a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FailedAttempt> .\n'
#  '\n'
#  'ns1:OperableHardware a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#HardwareDiagnosis> '
#  '.\n'
#  '\n'
#  'ns1:PR2 a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:ParameterInference a owl:Class ;\n'
#  '    rdfs:comment "A reasoning task where the value of a parameter is '
#  'determined." ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onClass '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> ;\n'
#  '            owl:onProperty ns1:hasInferredParameter ;\n'
#  '            owl:qualifiedCardinality "1"^^xsd:nonNegativeInteger ],\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#Reasoning> .\n'
#  '\n'
#  'ns1:Pin a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Connector .\n'
#  '\n'
#  'ns1:Pose_MapFrame a owl:NamedIndividual ;\n'
#  '    ns1:quaternion "0.0 0.0 0.0 1.0"^^xsd:string ;\n'
#  '    ns1:translation "0.0 0.0 0.0"^^xsd:string .\n'
#  '\n'
#  'ns1:PouringInto a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Pouring .\n'
#  '\n'
#  'ns1:PouringOnto a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Pouring .\n'
#  '\n'
#  'ns1:Proprioception a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Perception .\n'
#  '\n'
#  'ns1:Reasoner a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> .\n'
#  '\n'
#  'ns1:RechargeableBattery a owl:Class ;\n'
#  '    rdfs:comment "Batteries which may be recharged (cf. ChargingABattery)." '
#  ';\n'
#  '    rdfs:subClassOf ns1:Battery .\n'
#  '\n'
#  'ns1:ResourceMissing a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Infeasibility> .\n'
#  '\n'
#  'ns1:ResourceNotFound a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FailedAttempt> .\n'
#  '\n'
#  'ns1:RfidPerception a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Perception .\n'
#  '\n'
#  'ns1:RingFinger a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:RobovieMR2 a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:SemanticEnvironmentMap a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Map .\n'
#  '\n'
#  'ns1:Serving a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Actuating> .\n'
#  '\n'
#  'ns1:Slicing a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Cutting .\n'
#  '\n'
#  'ns1:Stirring a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Mixing> .\n'
#  '\n'
#  'ns1:StreetLight a owl:Class ;\n'
#  '    rdfs:comment "The collection of all streetlights." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalLightingDevice .\n'
#  '\n'
#  'ns1:TUM_Rosie a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:WheeledRobot .\n'
#  '\n'
#  'ns1:Thumb a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Finger .\n'
#  '\n'
#  'ns1:TouchPerception a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Perception .\n'
#  '\n'
#  'ns1:Towel a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TextileArtifact .\n'
#  '\n'
#  'ns1:UndefinedReference a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> .\n'
#  '\n'
#  'ns1:Ungraspable a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Inability> .\n'
#  '\n'
#  'ns1:Unliftable a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Inability> .\n'
#  '\n'
#  'ns1:UnpoweredHardware a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:InoperableHardware .\n'
#  '\n'
#  'ns1:Unreachable a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Inability> .\n'
#  '\n'
#  'ns1:WaitUntil a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:TemporalConstraint .\n'
#  '\n'
#  'ns1:WallMirror a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedFurniture> '
#  '.\n'
#  '\n'
#  'ns1:WasteBasket a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedFurniture> '
#  '.\n'
#  '\n'
#  'ns1:Water a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Fluid> .\n'
#  '\n'
#  'ns1:Wheel a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#DesignedComponent> '
#  '.\n'
#  '\n'
#  'ns1:areaOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:avoidedObject a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  'ns1:causedBy a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  'ns1:connectedTo-Rigidly a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:connectedTo .\n'
#  '\n'
#  'ns1:dangerousPart a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasPhysicalComponent> .\n'
#  '\n'
#  'ns1:depthOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasDepth> .\n'
#  '\n'
#  'ns1:describedInMap a owl:ObjectProperty ;\n'
#  '    rdfs:range ns1:Map ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#isPartOf> .\n'
#  '\n'
#  'ns1:detectedArtifact a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:detectedObject,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#involvesArtifact> .\n'
#  '\n'
#  'ns1:detectedPerson a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:detectedAgent .\n'
#  '\n'
#  'ns1:deviceUsed a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#involvesArtifact> .\n'
#  '\n'
#  'ns1:doorHingedTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:hingedTo .\n'
#  '\n'
#  'ns1:duration a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasEventTime> '
#  '.\n'
#  '\n'
#  'ns1:electricalPart a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasPhysicalComponent> .\n'
#  '\n'
#  'ns1:endTime a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasEventEnd> .\n'
#  '\n'
#  'ns1:firstName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:floorNumber a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:frameName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:fromLocation a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor,\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#involvesPlace> .\n'
#  '\n'
#  'ns1:fromState a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> .\n'
#  '\n'
#  'ns1:fullName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:goalLocation a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:eventOccursAt .\n'
#  '\n'
#  'ns1:hasAffordance a owl:AsymmetricProperty,\n'
#  '        owl:InverseFunctionalProperty,\n'
#  '        owl:IrreflexiveProperty,\n'
#  '        owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasQuality> .\n'
#  '\n'
#  'ns1:hasArity a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has arity" ;\n'
#  '    rdfs:range xsd:int ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:hasFirstProcedureArgument a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:hasProcedureArgument .\n'
#  '\n'
#  'ns1:hasFunctor a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has functor" ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:hasLifetime a owl:ObjectProperty .\n'
#  '\n'
#  'ns1:hasModulePath a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has module path" ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:hasPoseData a owl:DatatypeProperty ;\n'
#  '    rdfs:label "has pose data" ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasLocalizationParameter> .\n'
#  '\n'
#  'ns1:hasResolution a owl:ObjectProperty ;\n'
#  '    rdfs:label "has resolution" ;\n'
#  '    rdfs:domain '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#PhysicalObject> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> .\n'
#  '\n'
#  'ns1:hasSamplingRate a owl:ObjectProperty ;\n'
#  '    rdfs:label "has sampling rate" ;\n'
#  '    rdfs:domain ns1:SensorDevice ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> .\n'
#  '\n'
#  'ns1:hasSensorRange a owl:ObjectProperty ;\n'
#  '    rdfs:label "has sensor range" ;\n'
#  '    rdfs:domain ns1:SensorDevice ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> .\n'
#  '\n'
#  'ns1:hasVisual a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:boolean ;\n'
#  '    rdfs:subPropertyOf ns1:visualHint .\n'
#  '\n'
#  'ns1:hasXScale a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:hasYScale a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:hasZScale a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:heightOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasHeight> .\n'
#  '\n'
#  'ns1:inFieldOfView a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:inReachOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:inputsDestroyed a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:inputsRemaining a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:isAboveOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> ;\n'
#  '    owl:inverseOf ns1:isBelowOf .\n'
#  '\n'
#  'ns1:isBehindOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> ;\n'
#  '    owl:inverseOf ns1:isInFrontOf .\n'
#  '\n'
#  'ns1:isInCenterOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:isInsideOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:isLeftOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:isNextTo ;\n'
#  '    owl:inverseOf ns1:isRightOf .\n'
#  '\n'
#  'ns1:isOntopOf a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:lastName a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:nameString .\n'
#  '\n'
#  'ns1:lightConeAngle a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "The opening angle of spot lights. Must be below or equal '
#  'pi/2. Default is pi/3." ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightDirection a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "determines orientation of spot lights." ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightDistance a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "determines light attenuation. I guess threejs interprets '
#  'this as \\"the light shines lightDistance meters\\" (or so)" ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightExponent a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "Used as exponent in spot effect computation: '
#  'effect=x^exponent. Exponents below 1 make light brighter, above darker. '
#  'Default value is 10. Only meaningful for spotlights." ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightIntensity a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "numeric value of the light\'s strength/intensity. Default '
#  'is 1." ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:lightTarget a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> .\n'
#  '\n'
#  'ns1:lightType a owl:DatatypeProperty ;\n'
#  '    rdfs:comment "One of \'spot\', \'point\', or \'directional\'. '
#  'Corresponds to different light types used in Computer Graphics." ;\n'
#  '    rdfs:range [ a rdfs:Datatype ;\n'
#  '            owl:oneOf [ a rdf:List ;\n'
#  '                    rdf:first "directional" ;\n'
#  '                    rdf:rest [ a rdf:List ;\n'
#  '                            rdf:first "point" ;\n'
#  '                            rdf:rest [ a rdf:List ;\n'
#  '                                    rdf:first "spot" ;\n'
#  '                                    rdf:rest () ] ] ] ] ;\n'
#  '    rdfs:subPropertyOf ns1:lightParameter .\n'
#  '\n'
#  'ns1:linkToImageFile a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:mainColorOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range <http://www.ease-crc.org/ont/SOMA.owl#array_double> ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasRGBValue> .\n'
#  '\n'
#  'ns1:maxJointValue a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf ns1:jointLimitParameters .\n'
#  '\n'
#  'ns1:minJointValue a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf ns1:jointLimitParameters .\n'
#  '\n'
#  'ns1:near a owl:ObjectProperty ;\n'
#  '    rdfs:comment "This intentionally-vague predicate relates spatial things '
#  'that are relatively near each other. (near THIS THAT) means that the '
#  'distance between THIS and THAT is such that -- given the situation at hand '
#  'and the sorts of things that THIS and THAT are -- they would be considered '
#  'near each other by most observers. Note that an object is near itself, '
#  'anything it touches, and any part of itself. When appropriate, use a more '
#  'precisely-defined predicate such as nearToDegree, nearRelativeTo, '
#  'nearForRolesInEventType, nearnessForRolesInEventType, touches_Directly, or '
#  'physicalParts."^^xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:numberOfLevels a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:positiveInteger ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:numberOfStories a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:positiveInteger ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:objectID a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:int ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> .\n'
#  '\n'
#  'ns1:objectOfStateChange a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:objectRemoved a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:objectTransported a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:objectActedOn .\n'
#  '\n'
#  'ns1:outputsCreated a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:postActor .\n'
#  '\n'
#  'ns1:pathToCadModel a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasFilePath> .\n'
#  '\n'
#  'ns1:performedInMap a owl:ObjectProperty ;\n'
#  '    rdfs:range ns1:Map ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  'ns1:prismaticallyConnectedTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:connectedTo .\n'
#  '\n'
#  'ns1:processStarted a owl:ObjectProperty ;\n'
#  '    rdfs:domain '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Event> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasConstituent> .\n'
#  '\n'
#  'ns1:processStopped a owl:ObjectProperty ;\n'
#  '    rdfs:domain '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Event> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasConstituent> .\n'
#  '\n'
#  'ns1:quaternion a owl:DatatypeProperty ;\n'
#  '    rdfs:range <http://www.ease-crc.org/ont/SOMA.owl#array_double> ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasOrientationVector> .\n'
#  '\n'
#  'ns1:relativeTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> .\n'
#  '\n'
#  'ns1:roomNumber a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:scale a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> .\n'
#  '\n'
#  'ns1:startTime a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:double ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasEventBegin> '
#  '.\n'
#  '\n'
#  'ns1:storedAtPlace a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:streetNumber a owl:DatatypeProperty,\n'
#  '        owl:FunctionalProperty ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf ns1:buildingParameter .\n'
#  '\n'
#  'ns1:temperatureOfObject a owl:DatatypeProperty ;\n'
#  '    rdfs:range xsd:float ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  'ns1:thermicallyConnectedTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:connectedTo .\n'
#  '\n'
#  'ns1:toLocation a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor,\n'
# ...
#  'See also the more general predicate eventPartiallyOccursAt, which relates an '
#  'event to any instance of SpatialThing_Localized in which some sub-event of '
#  'it occurs.""" ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:isNextTo a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:jointLimitParameters a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  'ns1:postActor a owl:ObjectProperty ;\n'
#  '    rdfs:range owl:Thing ;\n'
#  '    rdfs:subPropertyOf ns1:actor .\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#TopologicalMap> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Arm> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#DependentPlace> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#DesignedFurniture> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#ExitOGPWorkflow> a owl:Class ;\n'
#  '    rdfs:comment """A final Task in a OGPWorkflow, which is simply to return '
#  'some information as a "result" of the workflow\'s execution.\\r\n'
#  '\\r\n'
#  'This task only uses outputs. The values for the outputs are calculated by '
#  'the KnowRob workflow interpreter based on the Bindings between roles that '
#  'exist in the workflow.""" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onClass '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Entity> ;\n'
#  '            owl:onProperty '
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesOutput> ;\n'
#  '            owl:qualifiedCardinality "0"^^xsd:nonNegativeInteger ],\n'
#  '        <http://www.ease-crc.org/ont/SOMA.owl#OGPTask> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#FailedAttempt> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Hand> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#HardwareDiagnosis> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Leg> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Mixing> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#ProcessType> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Reasoning> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesInput> a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesOutput> a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasPhysicalComponent> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#involvesArtifact> a owl:ObjectProperty '
#  '.\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#involvesPlace> a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Entity> a owl:Class '
#  '.\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#InformationEntity> a '
#  'owl:Class .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasConstituent> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  'geos:SpatialObject a owl:Class ;\n'
#  '    rdfs:label "SpatialObject" ;\n'
#  '    rdfs:subClassOf owl:Thing .\n'
#  '\n'
#  'geos:sfContains a owl:ObjectProperty ;\n'
#  '    rdfs:label "sfContains" .\n'
#  '\n'
#  'geos:wktLiteral a rdfs:Datatype ;\n'
#  '    rdfs:label "wktLiteral" .\n'
#  '\n'
#  'TRASH:ArmMovement a owl:Class ;\n'
#  '    rdfs:subClassOf TRASH:StandingAction .\n'
#  '\n'
#  'TRASH:GeneralTrashBin a owl:Class ;\n'
#  '    rdfs:label "GeneralTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:GlassTrashBin a owl:Class ;\n'
#  '    rdfs:label "GlassTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:LivingCreature a owl:Class ;\n'
#  '    rdfs:label "LivingCreature" ;\n'
#  '    rdfs:subClassOf TRASH:NonTrashObject .\n'
#  '\n'
#  'TRASH:LostAndFound a owl:Class ;\n'
#  '    rdfs:label "LostAndFound" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:bringTo ;\n'
#  '            owl:someValuesFrom TRASH:LostFound ],\n'
#  '        TRASH:NonTrashObject .\n'
#  '\n'
#  'TRASH:MovableObject a owl:Class ;\n'
#  '    rdfs:label "MovableObject" ;\n'
#  '    rdfs:subClassOf TRASH:Object .\n'
#  '\n'
#  'TRASH:OrganicTrashBin a owl:Class ;\n'
#  '    rdfs:label "OrganicTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:PaperTrashBin a owl:Class ;\n'
#  '    rdfs:label "PaperTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:PlasticTrashBin a owl:Class ;\n'
#  '    rdfs:label "PlasticTrashBin" ;\n'
#  '    rdfs:subClassOf TRASH:TrashBin .\n'
#  '\n'
#  'TRASH:Square a owl:Class ;\n'
#  '    rdfs:label "Square" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:sfContains ;\n'
#  '            owl:someValuesFrom TRASH:Obstacle ],\n'
#  '        [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:sfContains ;\n'
#  '            owl:someValuesFrom TRASH:TrashBin ],\n'
#  '        TRASH:StaticObject .\n'
#  '\n'
#  'TRASH:StandingAction a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#PhysicalAction> .\n'
#  '\n'
#  'TRASH:Vehicle a owl:Class ;\n'
#  '    rdfs:label "Vehicle" ;\n'
#  '    rdfs:subClassOf TRASH:NonTrashObject .\n'
#  '\n'
#  'TRASH:grab a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf owl:topObjectProperty .\n'
#  '\n'
#  'TRASH:performs a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf owl:topObjectProperty .\n'
#  '\n'
#  'TRASH:release a owl:ObjectProperty .\n'
#  '\n'
#  'TRASH:uses a owl:ObjectProperty .\n'
#  '\n'
#  'ns1:LocationConstraint a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:SpatialConstraint .\n'
#  '\n'
#  'ns1:SpatialConstraint a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Constraint .\n'
#  '\n'
#  'ns1:trajectory-Complete a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:eventOccursAt .\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#MetricMap> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Actuating> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Appliance> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#DesignedComponent> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#Inability> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#PhaseTransition> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#array_double> a rdfs:Datatype .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Event> a owl:Class .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#definesTask> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegion> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#isRelatedToConcept> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  'TRASH:NonTrashObject a owl:Class ;\n'
#  '    rdfs:label "NonTrashObject" ;\n'
#  '    rdfs:subClassOf TRASH:MovableObject .\n'
#  '\n'
#  'TRASH:Object a owl:Class ;\n'
#  '    rdfs:label "TraceableObject"^^xsd:string ;\n'
#  '    rdfs:subClassOf geos:SpatialObject .\n'
#  '\n'
#  'ns1:Map a owl:Class ;\n'
#  '    rdfs:subClassOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Place> .\n'
#  '\n'
#  'ns1:OrientationConstraint a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:SpatialConstraint .\n'
#  '\n'
#  'ns1:WheeledRobot a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/urdf.owl#Robot> .\n'
#  '\n'
#  'ns1:connectedTo a owl:ObjectProperty ;\n'
#  '    rdfs:comment "An instance of ConnectionPredicate. (connectedTo OBJ1 '
#  'OBJ2) means that OBJ1 and OBJ2 are (directly or indirectly) physically '
#  'connected in a way that allows at most only limited types of relative motion '
#  'between them. A hinged connection, for example, allows limited rotational '
#  'motion between OBJ1 and OBJ2. In many cases, being connectedTo implicitly '
#  'involves another object(s); e.g. a door is connectedTo a door frame by a '
#  'hinge, which is itself connectedTo_Directly (q.v.) both the door and the '
#  'frame."^^xsd:string ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> .\n'
#  '\n'
#  'ns1:nameString a owl:DatatypeProperty ;\n'
#  '    rdfs:domain owl:Thing ;\n'
#  '    rdfs:range xsd:string ;\n'
#  '    rdfs:subPropertyOf <http://www.ease-crc.org/ont/SOMA.owl#hasNameString> '
#  '.\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#MapBuiltFromSensorData> a owl:Class ;\n'
#  '    rdfs:subClassOf <http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#FaultySoftware> a owl:Class .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#OGPTask> a owl:Class ;\n'
#  '    rdfs:comment """A Task to be interpreted by the KnowRob Workflow '
#  'interpreter.\\r\n'
#  '\\r\n'
#  'Usually, has a non-empty set of input (Role or Parameter)s, and a non-empty '
#  'set of output (Role or Parameter)s-- however, eiter or both of these sets '
#  'may be empty in the case of tasks with trivial input/outputs.""" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:allValuesFrom [ a owl:Class ;\n'
#  '                    owl:unionOf ( '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> ) ] ;\n'
#  '            owl:onProperty '
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesInput> ],\n'
#  '        [ a owl:Restriction ;\n'
#  '            owl:allValuesFrom [ a owl:Class ;\n'
#  '                    owl:unionOf ( '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> ) ] ;\n'
#  '            owl:onProperty '
#  '<http://www.ease-crc.org/ont/SOMA.owl#definesOutput> ],\n'
#  '        <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Task> .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> a owl:Class .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#associatedWith> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> a '
#  'owl:DatatypeProperty .\n'
#  '\n'
#  'TRASH:Material a owl:Class ;\n'
#  '    rdfs:label "Material" ;\n'
#  '    rdfs:subClassOf TRASH:TrashObject .\n'
#  '\n'
#  'TRASH:MovingAction a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#PhysicalAction> .\n'
#  '\n'
#  'TRASH:RecyclableMaterial a owl:Class ;\n'
#  '    rdfs:label "RecyclableMaterial" ;\n'
#  '    rdfs:subClassOf TRASH:Material .\n'
#  '\n'
#  'TRASH:StaticObject a owl:Class ;\n'
#  '    rdfs:label "StaticObject" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:hasGeometry ;\n'
#  '            owl:someValuesFrom geos:Geometry ],\n'
#  '        TRASH:Object .\n'
#  '\n'
#  'ns1:ElectricalLightingDevice a owl:Class ;\n'
#  '    rdfs:comment "Devices that provide light by transforming electrical '
#  'current into light energy." ;\n'
#  '    rdfs:subClassOf ns1:ElectricalDevice .\n'
#  '\n'
#  'ns1:Finger a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#PhysicalEffector> '
#  '.\n'
#  '\n'
#  'ns1:Perception a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#MentalAction> .\n'
#  '\n'
#  'ns1:buildingParameter a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  'ns1:objectActedOn a owl:ObjectProperty ;\n'
#  '    rdfs:subPropertyOf ns1:preActor .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Concept> a owl:Class '
#  '.\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Parameter> a '
#  'owl:Class .\n'
#  '\n'
#  'TRASH:TrashObject a owl:Class ;\n'
#  '    rdfs:label "TrashObject" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:madeOf ;\n'
#  '            owl:someValuesFrom TRASH:Material ],\n'
#  '        [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putInto ;\n'
#  '            owl:someValuesFrom TRASH:TrashBin ],\n'
#  '        TRASH:MovableObject .\n'
#  '\n'
#  'ns1:ElectricalDevice a owl:Class ;\n'
#  '    rdfs:subClassOf <http://www.ease-crc.org/ont/SOMA.owl#Appliance> .\n'
#  '\n'
#  'ns1:KeepRelativeLocation a owl:Class ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty ns1:dependsOnConcept ;\n'
#  '            owl:someValuesFrom '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Role> ],\n'
#  '        ns1:LocationConstraint .\n'
#  '\n'
#  'ns1:lightParameter a owl:DatatypeProperty ;\n'
#  '    rdfs:subPropertyOf '
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasRegionDataValue> '
#  '.\n'
#  '\n'
#  '<http://knowrob.org/kb/srdl2-comp.owl#EnvironmentMap> a owl:Class ;\n'
#  '    rdfs:subClassOf ns1:Map .\n'
#  '\n'
#  '<http://www.ease-crc.org/ont/SOMA.owl#hasShapeParameter> a '
#  'owl:DatatypeProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasDataValue> a '
#  'owl:DatatypeProperty .\n'
#  '\n'
#  'ns1:preActor a owl:ObjectProperty ;\n'
#  '    rdfs:comment "An ActorSlot (q.v.) that relates an event to those of its '
#  'participants that pre-exist it. (preActors EVENT OBJECT) means that OBJECT '
#  'is a participant (see actors) in EVENT and that OBJECT exists before EVENT '
#  'begins. Note that OBJECT also exists during at least part of EVENT (as '
#  'actors generalizes to temporallyIntersects). preActors is a very general '
#  'actor-slot, subsuming doneBy, objectActedOn, objectMoving, and many '
#  'others."^^xsd:string ;\n'
#  '    rdfs:range owl:Thing ;\n'
#  '    rdfs:subPropertyOf ns1:actor .\n'
#  '\n'
#  'TRASH:TrashBin a owl:Class ;\n'
#  '    rdfs:label "TrashBin" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:hasMetricVolume ;\n'
#  '            owl:someValuesFrom xsd:double ],\n'
#  '        TRASH:StaticObject .\n'
#  '\n'
#  'owl:topObjectProperty a owl:ObjectProperty .\n'
#  '\n'
#  '<http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#hasLocation> a '
#  'owl:ObjectProperty .\n'
#  '\n'
#  'TRASH:GlassMaterial a owl:Class ;\n'
#  '    rdfs:label "GlassMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoGlassTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:GlassTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'TRASH:Obstacle a owl:Class ;\n'
#  '    rdfs:label "Obstacle" ;\n'
#  '    rdfs:subClassOf TRASH:StaticObject .\n'
#  '\n'
#  'TRASH:PaperMaterial a owl:Class ;\n'
#  '    rdfs:label "PaperMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoPaperTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:PaperTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'TRASH:PlasticMaterial a owl:Class ;\n'
#  '    rdfs:label "PlasticMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoPlasticTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:PlasticTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'geos:Geometry a owl:Class ;\n'
#  '    rdfs:label "Geometry" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty geos:asWKT ;\n'
#  '            owl:someValuesFrom geos:wktLiteral ],\n'
#  '        geos:SpatialObject .\n'
#  '\n'
#  'TRASH:OrganicMaterial a owl:Class ;\n'
#  '    rdfs:label "OrganicMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoOrganicTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:OrganicTrashBin ],\n'
#  '        TRASH:RecyclableMaterial .\n'
#  '\n'
#  'TRASH:OtherMaterial a owl:Class ;\n'
#  '    rdfs:label "OtherMaterial" ;\n'
#  '    rdfs:subClassOf [ a owl:Restriction ;\n'
#  '            owl:onProperty TRASH:putIntoGeneralTrashBin ;\n'
#  '            owl:someValuesFrom TRASH:GeneralTrashBin ],\n'
#  '        TRASH:NonRecyclableMaterial .\n'
#  '\n')

# %%
g.serialize(destination="./data/ontology_kw.ttl")
# Out:
# <Graph identifier=N3cd2ff639da647d0801c6f85e8b7dd71 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Queries testing

# %%
g = rdflib.Graph()
g.parse("./data/ontology_kw.ttl")
# Out:
# <Graph identifier=N2abeb75c377b4f9a84070b32f56c6bfc (<class 'rdflib.graph.Graph'>)>

# %%
import shapely.wkt

knows_query = """
PREFIX geos: <http://www.opengis.net/ont/geosparql#>
PREFIX TRASH: <http://www.trashrobot.com/onto/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

select distinct ?s ?co ?pco where { 
	# ?s rdfs:label "trashbin2" .
    # ?s geos:hasGeometry ?g .
    # ?g geos:asWKT	?co .
    # ?s geos:hasCentroid ?p .
    # ?p geos:asWKT ?pco .
} limit 100"""

qres = g.query(knows_query)
for row in qres:
    print(f"{row.s}, {row.co}, {row.pco}")
    print((shapely.wkt.loads(row.pco).x, shapely.wkt.loads(row.pco).y))
# Out:
# http://www.trashrobot.com/onto/trashbin2, POLYGON ((4.8648450858990895 52.33363922345298, 4.86487140140845 52.333639339617775, 4.864869603145313 52.33362441908744, 4.864845909713331 52.33362512058333, 4.8648450858990895 52.33363922345298)), POINT (4.864858126018167 52.3336321496965)
# (4.864858126018167, 52.3336321496965)

# %%
#g = rdflib.Graph()
#g.parse("http://danbri.org/foaf.rdf#")

knows_query = """
PREFIX geos: <http://www.opengis.net/ont/geosparql#>
PREFIX TRASH: <http://www.trashrobot.com/onto/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

select distinct ?s ?c where { 
    # ?s geos:asWKT	?c .
} limit 100"""

qres = g.query(knows_query)
for row in qres:
    print(f"{row.s}, {row.c}")
# Out:
# http://www.trashrobot.com/onto/tree1Geo, POLYGON ((4.865020643304397 52.33366524064013, 4.865048005384971 52.3336658772791, 4.865046957576984 52.3336475583801, 4.865020846520131 52.33364795905172, 4.865020643304397 52.33366524064013))
# N81475d23925b4937867fde484d905640, POINT (4.865034243973181 52.33365672745673)
# http://www.trashrobot.com/onto/tree2Geo, POLYGON ((4.865102365154075 52.333733957342176, 4.865128891245001 52.333734074378675, 4.865129061062091 52.333719630066014, 4.865102528914593 52.33372002889785, 4.865102365154075 52.333733957342176))
# N5b66f0c4c5b244f386539a6e1164a978, POINT (4.865115791985217 52.33372692224459)
# http://www.trashrobot.com/onto/tree3Geo, POLYGON ((4.865148505806162 52.33406501071023, 4.865239116241276 52.33406541043299, 4.865239678949748 52.334017537856056, 4.865149073464112 52.33401672543926, 4.865148505806162 52.33406501071023))
# N5eecc417068a4608a20c62c782ae596a, POINT (4.865194028802701 52.33404117068044)
# http://www.trashrobot.com/onto/stairs1Geo, POLYGON ((4.865712099721179 52.334306406820794, 4.865760600356443 52.33430703327133, 4.865761017537423 52.334128071135474, 4.865750905000111 52.334128645646686, 4.86575075527825 52.33405533630606, 4.865742329389108 52.33405571189114, 4.865742664938734 52.33396976525989, 4.865733243081567 52.33396889830709, 4.865734340816954 52.333932790493, 4.86572356433506 52.3339325366438, 4.865716742746486 52.334054464163934, 4.865712099721179 52.334306406820794))
# N94065f802ebe4796b810cbfed313bf2f, POINT (4.865735283195604 52.33415535115538)
# http://www.trashrobot.com/onto/tree4Geo, POLYGON ((4.865727171410244 52.333883542512254, 4.865754457906683 52.33388345640125, 4.86575465175158 52.3338669486145, 4.865727702105574 52.333867036209995, 4.865727171410244 52.333883542512254))
# Ne7bfc14c0188486ba19af974420ceeaa, POINT (4.865740995769411 52.333875263023245)
# http://www.trashrobot.com/onto/tent1Geo, POLYGON ((4.865498688212789 52.334278587984905, 4.865644669894641 52.33423961077055, 4.86554078214148 52.33410770277901, 4.865394730485205 52.334152663938816, 4.865498688212789 52.334278587984905))
# N47576eb35ae646b1ad7e159030c60d8e, POINT (4.865519939052319 52.334194217685614)
# http://www.trashrobot.com/onto/tent2Geo, POLYGON ((4.865382647300843 52.33413460591841, 4.865526052656866 52.334085505946845, 4.865478153508663 52.33403370526517, 4.865334789492862 52.33407929727489, 4.865382647300843 52.33413460591841))
# N50f19ab7eda3401ea487fd3ecff88c65, POINT (4.865429877073712 52.334083553719765)
# http://www.trashrobot.com/onto/pole1Geo, POLYGON ((4.86551837573517 52.33401117959129, 4.8655493819400615 52.334004061510626, 4.865529867670288 52.333985032460916, 4.865502761485261 52.33399619816106, 4.86551837573517 52.33401117959129))
# N9aeee9a9efd744b286649415ef056bdd, POINT (4.865525652881971 52.33399892925497)
# http://www.trashrobot.com/onto/pole2Geo, POLYGON ((4.865374436095665 52.333774764760186, 4.865363375107365 52.33376423686308, 4.865338294784355 52.33377097798662, 4.865349360504581 52.33378110286393, 4.865374436095665 52.333774764760186))
# N28b24fa9623e42bca6ab5846bdfc59dc, POINT (4.865356417635749 52.3337727423371)
# http://www.trashrobot.com/onto/trashbin1Geo, POLYGON ((4.865807159202763 52.333622911343326, 4.865836768875372 52.333622638765384, 4.865836986536229 52.33360409974587, 4.86580803003127 52.333604778244876, 4.865807159202763 52.333622911343326))
# N41f78d826aab48ce9832362ccc2c6844, POINT (4.865822290591065 52.33361364085224)
# http://www.trashrobot.com/onto/trashbin2Geo, POLYGON ((4.8648450858990895 52.33363922345298, 4.86487140140845 52.333639339617775, 4.864869603145313 52.33362441908744, 4.864845909713331 52.33362512058333, 4.8648450858990895 52.33363922345298))
# Nef2f72bbd46f46f0b5838758c448c4cb, POINT (4.864858126018167 52.3336321496965)
# http://www.trashrobot.com/onto/trashbin3Geo, POLYGON ((4.865160085170681 52.33393140910959, 4.865179164041298 52.33393149327904, 4.865179310912214 52.33391899959377, 4.8651608899388625 52.33391891832682, 4.865160085170681 52.33393140910959))
# Nf5de7a0461f246f2a56ea44b6b7610eb, POINT (4.865169861124478 52.333925241604604)
# http://www.trashrobot.com/onto/trashbin4Geo, POLYGON ((4.865305990255049 52.33422446040352, 4.865327042941315 52.33422455325422, 4.865326565030923 52.33420923551329, 4.865308139200152 52.33420955729118, 4.865305990255049 52.33422446040352))
# N340057650d6948f49564399effc78259, POINT (4.865316971817446 52.33421712043261)
# http://www.trashrobot.com/onto/trashbin5Geo, POLYGON ((4.865623795915216 52.334082277593424, 4.865644195374122 52.334081964465504, 4.8656450047425475 52.33406907065753, 4.865623952129151 52.33406897786359, 4.865623795915216 52.334082277593424))
# N828634e195614c14a395e0dc31768ee5, POINT (4.865634184337034 52.33407553774319)
# http://www.trashrobot.com/onto/lostFound1Geo, POLYGON ((4.865109582132319 52.33422542405279, 4.865149061841612 52.33422509443258, 4.865146873093714 52.334201406000965, 4.865108203929449 52.33420274680405, 4.865109582132319 52.33422542405279))
# N1471763193874bb8841c5e893c4af8c5, POINT (4.865128577256286 52.334213700908876)
# http://www.trashrobot.com/onto/trashbin6Geo, POLYGON ((4.8648989900643365 52.3337405911906, 4.864918726741546 52.333740678305794, 4.864918076209215 52.33372606512473, 4.8648983395385015 52.33372597800939, 4.8648989900643365 52.3337405911906))
# Nec49e7d995b3407eb28f7b1b6b4f287d, POINT (4.864908533138398 52.33373332815803)
# http://www.trashrobot.com/onto/trashbin7Geo, POLYGON ((4.865894748062195 52.333930507960694, 4.865918596652262 52.333930613023874, 4.865917957615872 52.33391499229308, 4.865895741935801 52.33391590203095, 4.865894748062195 52.333930507960694))
# Nef3181023a594d1bbc04589436b38bfe, POINT (4.865906892536651 52.33392309147284)
# http://www.trashrobot.com/onto/trashbin8Geo, POLYGON ((4.865647013068398 52.334296815162176, 4.865670039482551 52.334296916651084, 4.865668560406992 52.334282803628476, 4.8656471669095716 52.33428371694397, 4.865647013068398 52.334296815162176))
# Naae51a616ba846c2a34db57489d4527e, POINT (4.865658340881701 52.33429014126585)
# http://www.trashrobot.com/onto/trashbin9Geo, POLYGON ((4.865208767995246 52.33369346701827, 4.865230155295318 52.333693057559245, 4.865228682300676 52.333678440752024, 4.865208927884841 52.33367986502159, 4.865208767995246 52.33369346701827))
# Na7a10fa96ee14eaeb1f61d665562d9f6, POINT (4.86521926944221 52.3336862921557)
# http://www.trashrobot.com/onto/trashbin10Geo, POLYGON ((4.8656093814393095 52.33392975422991, 4.865627538560571 52.33392429242289, 4.865615374685824 52.33390962849796, 4.865598034016471 52.33391559770584, 4.8656093814393095 52.33392975422991))
# N01d7ac9ef2c645a69cdfbd1d1e4a6c83, POINT (4.865612662386649 52.33391981961828)
# http://www.trashrobot.com/onto/beach1Geo, POLYGON ((4.86470859135835 52.3340662855176, 4.86501531166205 52.3340690630563, 4.86502372556948 52.3337487903794, 4.86471231810742 52.3337495511575, 4.86470859135835 52.3340662855176))
# N2bc2de62d92b4dfcaed02973dc0fd3ec, POINT (4.8648652815747875 52.33390802675483)
# http://www.trashrobot.com/onto/table8Geo, POLYGON ((4.86499650495455 52.3336212282298, 4.8650316070419 52.3336210186937, 4.86503365735617 52.3335984323746, 4.86499854243033 52.3335997351788, 4.86499650495455 52.3336212282298))
# Nfe75d288dc3d439cbef79522af4b0f46, POINT (4.865015222897371 52.33361010512947)
# http://www.trashrobot.com/onto/table9Geo, POLYGON ((4.86505004825995 52.3336211000705, 4.86508514606226 52.333621254941, 4.86508363993733 52.3335975596044, 4.86504911560627 52.333599229471, 4.86505004825995 52.3336211000705))
# N047d3c21d5664ff7b44a9f0fff58cdf7, POINT (4.865067222511663 52.33360980685743)
# http://www.trashrobot.com/onto/table10Geo, POLYGON ((4.86510120776849 52.3336213258105, 4.86513570640887 52.3336218424637, 4.86513359252621 52.3335992377706, 4.86509968021189 52.3335994525865, 4.86510120776849 52.3336213258105))
# Nab864f9e24fc4fe6ae86b670cc1e0a72, POINT (4.8651176425223674 52.33361049360291)
# http://www.trashrobot.com/onto/table11Geo, POLYGON ((4.86515396340783 52.3336375939916, 4.86518428934597 52.3336388211042, 4.86518391723231 52.33361986851, 4.8651916463624 52.3336202670486, 4.86518893757362 52.3335976597322, 4.86515262861317 52.333599321756, 4.86515236727764 52.3336215515283, 4.86515396340783 52.3336375939916))
# N77c6fac04b454b02ad28cb15a8794391, POINT (4.865170481372383 52.33361742633404)
# http://www.trashrobot.com/onto/table7Geo, POLYGON ((4.86521115080232 52.3335987526627, 4.86521087913861 52.3336218635638, 4.86524119459496 52.3336219972914, 4.86524146624289 52.3335988863903, 4.86521115080232 52.3335987526627))
# N3f083dbe5a0543028bf52bd3ce2b5efa, POINT (4.865226172694677 52.33361037497806)
# http://www.trashrobot.com/onto/table6Geo, POLYGON ((4.86526134697449 52.3335983550098, 4.86526105593422 52.3336231166897, 4.86529608712946 52.3336232712038, 4.86529637815019 52.3335985095238, 4.86526134697449 52.3335983550098))
# Nd3896eafb0dc498aa3158363b0ae5dbf, POINT (4.865278717047079 52.33361081310793)
# http://www.trashrobot.com/onto/table5Geo, POLYGON ((4.86531256578599 52.3335969300558, 4.86531225052331 52.3336237552092, 4.86534862907298 52.3336239156502, 4.86534894431369 52.3335970904967, 4.86531256578599 52.3335969300558))
# N07ffd1400b584d459edaa0e5f408867a, POINT (4.865330597423976 52.33361042285433)
# http://www.trashrobot.com/onto/table4Geo, POLYGON ((4.86536071425246 52.3335987932677, 4.8653604232676 52.3336235549479, 4.86539882284789 52.3336237242863, 4.86539911381132 52.333598962606, 4.86536071425246 52.3335987932677))
# N88313026d4404ef0860a62a85c8394be, POINT (4.865379768544806 52.33361125877813)
# http://www.trashrobot.com/onto/table3Geo, POLYGON ((4.86541123391492 52.3335996392395, 4.86541062309231 52.3336229550032, 4.86541702302229 52.3336229832245, 4.86541716831639 52.3336392861493, 4.86544175753019 52.333639394575, 4.86544093127671 52.3336237077217, 4.86544531260074 52.3336235206825, 4.86544390480015 52.3335999896598, 4.86541123391492 52.3335996392395))
# Nd03150f398434b799ce7f43757138afe, POINT (4.865428262002396 52.33361815859864)
# http://www.trashrobot.com/onto/table2Geo, POLYGON ((4.86546116582645 52.3336217333616, 4.86549451282946 52.3336218803909, 4.86549511391101 52.3335993900161, 4.86546007303604 52.3336000609504, 4.86546116582645 52.3336217333616))
# Naefaa68d02c643a6b8721a5816fe1589, POINT (4.86547781925123 52.33361067374755)
# http://www.trashrobot.com/onto/table1Geo, POLYGON ((4.86551741056934 52.3336226004174, 4.86553897307649 52.3336222827628, 4.86553923487323 52.3335999972501, 4.86551632259975 52.333600515312, 4.86551741056934 52.3336226004174))
# Nfb12d4e8b8a74387bbe5c625e0a215dd, POINT (4.865527997801337 52.333611236172956)
# http://www.trashrobot.com/onto/square1Geo, POLYGON ((4.86593529657669 52.3335094706968, 4.86470946102099 52.333504851471, 4.86470614490777 52.3341143213289, 4.86508781230435 52.3341128572158, 4.86510615036104 52.3343018645273, 4.86593748014087 52.3343086783451, 4.86593529657669 52.3335094706968))
# N5037ee646a564f52a308b1d3e6125f1b, POINT (4.865356432223756 52.33388141174779)

# %%
#g = rdflib.Graph()
#g.parse("http://danbri.org/foaf.rdf#")

knows_query = """
PREFIX geos: <http://www.opengis.net/ont/geosparql#>
PREFIX TRASH: <http://www.trashrobot.com/onto/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

select distinct ?s ?co where { 
	# ?s rdfs:label "paperTrashbin8" .
    # ?s geos:hasGeometry ?g .
    # ?g geos:asWKT	?co .
} limit 100"""

qres = g.query(knows_query)

coords = []

for row in qres:
    coords.append(row.co)

print(coords[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7680/176343751.py in <module>
#      20     coords.append(row.co)
#      21
# ---> 22 print(coords[0])
#
# IndexError: list index out of range

# %% [markdown]
# # Geosparql-example

# %%
from rdflib import Graph

g = Graph()
g.parse("geosparql-example.rdf")
# Out:
# <Graph identifier=N575cc36d78964fdaa19a2a632e226075 (<class 'rdflib.graph.Graph'>)>

# %%
print(g.serialize(format='ttl'))
# Out:
# @prefix geo: <http://www.opengis.net/ont/geosparql#> .
# @prefix my: <http://example.org/ApplicationSchema#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sf: <http://www.opengis.net/ont/sf#> .
#
# my:PlaceOfInterest a rdfs:Class ;
#     rdfs:subClassOf geo:Feature .
#
# my:A a my:PlaceOfInterest ;
#     my:hasExactGeometry my:AExactGeom ;
#     my:hasPointGeometry my:APointGeom .
#
# my:B a my:PlaceOfInterest ;
#     my:hasExactGeometry my:BExactGeom ;
#     my:hasPointGeometry my:BPointGeom .
#
# my:C a my:PlaceOfInterest ;
#     my:hasExactGeometry my:CExactGeom ;
#     my:hasPointGeometry my:CPointGeom .
#
# my:D a my:PlaceOfInterest ;
#     my:hasExactGeometry my:DExactGeom ;
#     my:hasPointGeometry my:DPointGeom .
#
# my:E a my:PlaceOfInterest ;
#     my:hasExactGeometry my:EExactGeom .
#
# my:F a my:PlaceOfInterest ;
#     my:hasExactGeometry my:FExactGeom .
#
# my:hasExactGeometry a rdf:Property ;
#     rdfs:subPropertyOf geo:hasDefaultGeometry,
#         geo:hasGeometry .
#
# my:hasPointGeometry a rdf:Property ;
#     rdfs:subPropertyOf geo:hasGeometry .
#
# my:AExactGeom a sf:Polygon ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84>
# 				Polygon((-83.6 34.1, -83.2 34.1, -83.2 34.5, -83.6 34.5, -83.6 34.1))
#
# 		"""^^geo:wktLiteral .
#
# my:APointGeom a sf:Point ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84> Point(-83.4 34.3)
#
# 		"""^^geo:wktLiteral .
#
# my:BExactGeom a sf:Polygon ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84>
# 				Polygon((-83.6 34.1, -83.4 34.1, -83.4 34.3, -83.6 34.3, -83.6 34.1))
#
# 		"""^^geo:wktLiteral .
#
# my:BPointGeom a sf:Point ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84> Point(-83.5 34.2)
#
# 		"""^^geo:wktLiteral .
#
# my:CExactGeom a sf:Polygon ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84>
# 				Polygon((-83.2 34.3, -83.0 34.3, -83.0 34.5, -83.2 34.5, -83.2 34.3))
#
# 		"""^^geo:wktLiteral .
#
# my:CPointGeom a sf:Point ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84> Point(-83.1 34.4)
#
# 		"""^^geo:wktLiteral .
#
# my:DExactGeom a sf:Polygon ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84>
# 				Polygon((-83.3 34.0, -83.1 34.0, -83.1 34.2, -83.3 34.2, -83.3 34.0))
#
# 		"""^^geo:wktLiteral .
#
# my:DPointGeom a sf:Point ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84> Point(-83.2 34.1)
#
# 		"""^^geo:wktLiteral .
#
# my:EExactGeom a sf:LineString ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84> LineString(-83.4 34.0, -83.3 34.3)
#
# 		"""^^geo:wktLiteral .
#
# my:FExactGeom a sf:Point ;
#     geo:asWKT """
#
# 				<http://www.opengis.net/def/crs/OGC/1.3/CRS84> Point(-83.4 34.4)
#
# 		"""^^geo:wktLiteral .

# %% [markdown]
# # Trash objects

# %%
gdf = gpd.read_file('./data/trash-objects.shp')

# %%
gdf
# Out:
#       id                       geometry
# 0    0.0  POINT (119462.424 482981.736)
# 1    1.0  POINT (119439.090 483049.632)
# 2    2.0  POINT (119441.226 482986.115)
# 3    3.0  POINT (119426.366 483008.700)
# 4    4.0  POINT (119462.170 483030.814)
# 5    5.0  POINT (119444.295 483047.021)
# 6    6.0  POINT (119423.987 483001.922)
# 7    7.0  POINT (119462.890 482991.558)
# 8    8.0  POINT (119437.980 483042.554)
# 9    9.0  POINT (119458.293 483039.069)
# 10  10.0  POINT (119427.905 483059.207)
# 11  11.0  POINT (119426.078 483022.587)
# 12  12.0  POINT (119433.033 482974.199)
# 13  13.0  POINT (119432.231 483046.115)
# 14  14.0  POINT (119396.111 483038.815)
# 15  15.0  POINT (119404.277 482971.517)
# 16  16.0  POINT (119395.683 483048.513)
# 17  17.0  POINT (119460.363 483018.658)
# 18  18.0  POINT (119394.654 482992.217)
# 19  19.0  POINT (119408.143 483000.261)

# %%
gdf = gdf.to_crs(4326)

# %%
names = []

for i in range(1,21):
    names.append(f'trashObject{i}')
    
gdf['Name'] = names

# %%
gdf['Class'] = 'PaperMaterial'

# %%
gdf
# Out:
#       id                  geometry           Name          Class
# 0    0.0  POINT (4.86582 52.33362)   trashObject1  PaperMaterial
# 1    1.0  POINT (4.86547 52.33422)   trashObject2  PaperMaterial
# 2    2.0  POINT (4.86551 52.33365)   trashObject3  PaperMaterial
# 3    3.0  POINT (4.86529 52.33386)   trashObject4  PaperMaterial
# 4    4.0  POINT (4.86581 52.33406)   trashObject5  PaperMaterial
# 5    5.0  POINT (4.86555 52.33420)   trashObject6  PaperMaterial
# 6    6.0  POINT (4.86525 52.33379)   trashObject7  PaperMaterial
# 7    7.0  POINT (4.86583 52.33370)   trashObject8  PaperMaterial
# 8    8.0  POINT (4.86545 52.33416)   trashObject9  PaperMaterial
# 9    9.0  POINT (4.86575 52.33413)  trashObject10  PaperMaterial
# 10  10.0  POINT (4.86530 52.33431)  trashObject11  PaperMaterial
# 11  11.0  POINT (4.86528 52.33398)  trashObject12  PaperMaterial
# 12  12.0  POINT (4.86539 52.33355)  trashObject13  PaperMaterial
# 13  13.0  POINT (4.86537 52.33419)  trashObject14  PaperMaterial
# 14  14.0  POINT (4.86484 52.33412)  trashObject15  PaperMaterial
# 15  15.0  POINT (4.86497 52.33352)  trashObject16  PaperMaterial
# 16  16.0  POINT (4.86483 52.33421)  trashObject17  PaperMaterial
# 17  17.0  POINT (4.86579 52.33395)  trashObject18  PaperMaterial
# 18  18.0  POINT (4.86482 52.33371)  trashObject19  PaperMaterial
# 19  19.0  POINT (4.86502 52.33378)  trashObject20  PaperMaterial

# %%
g_trash = Graph()

# %%
TRASH = Namespace("http://www.trashrobot.com/onto/")
SKOS = Namespace("http://www.w3.org/2004/02/skos/core#")
GEO = Namespace("http://www.opengis.net/ont/geosparql#")
SF = Namespace("http://www.opengis.net/ont/sf#")

g_trash.namespace_manager.bind('TRASH', URIRef('http://www.trashrobot.com/onto/'))

# %%
def test(row):
    ind_name = row.Name[0].lower() + row.Name[1:]
    geo_name = ind_name + "Geo"
    
    exec(f'g_trash.add((TRASH.{ind_name}, RDF.type, OWL.NamedIndividual))')
    exec(f'g_trash.add((TRASH.{ind_name}, RDF.type, TRASH.{row.Class}))')
    exec(f'g_trash.add((TRASH.{ind_name}, RDFS.label, Literal("{ind_name}")))')
    
    exec(f'g_trash.add((TRASH.{geo_name}, RDF.type, GEO.Geometry))')
    exec(f'g_trash.add((TRASH.{geo_name}, RDFS.label, Literal("{geo_name}")))')
    exec(f'g_trash.add((TRASH.{geo_name}, GEO.asWKT, Literal(\"{row.geometry}\", datatype=GEO.wktLiteral)))')
    
    exec(f'g_trash.add((TRASH.{ind_name}, GEO.hasGeometry, TRASH.{geo_name}))')
    
gdf.apply(lambda x: test(x), axis=1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# dtype: object

# %%
pprint.pprint(g_trash.serialize(format="ttl"))
# Out:
# ('@prefix TRASH: <http://www.trashrobot.com/onto/> .\n'
#  '@prefix ns1: <http://www.opengis.net/ont/geosparql#> .\n'
#  '@prefix owl: <http://www.w3.org/2002/07/owl#> .\n'
#  '@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .\n'
#  '\n'
#  'TRASH:trashObject1 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject1" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject1Geo .\n'
#  '\n'
#  'TRASH:trashObject10 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject10" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject10Geo .\n'
#  '\n'
#  'TRASH:trashObject11 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject11" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject11Geo .\n'
#  '\n'
#  'TRASH:trashObject12 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject12" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject12Geo .\n'
#  '\n'
#  'TRASH:trashObject13 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject13" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject13Geo .\n'
#  '\n'
#  'TRASH:trashObject14 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject14" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject14Geo .\n'
#  '\n'
#  'TRASH:trashObject15 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject15" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject15Geo .\n'
#  '\n'
#  'TRASH:trashObject16 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject16" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject16Geo .\n'
#  '\n'
#  'TRASH:trashObject17 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject17" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject17Geo .\n'
#  '\n'
#  'TRASH:trashObject18 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject18" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject18Geo .\n'
#  '\n'
#  'TRASH:trashObject19 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject19" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject19Geo .\n'
#  '\n'
#  'TRASH:trashObject2 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject2" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject2Geo .\n'
#  '\n'
#  'TRASH:trashObject20 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject20" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject20Geo .\n'
#  '\n'
#  'TRASH:trashObject3 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject3" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject3Geo .\n'
#  '\n'
#  'TRASH:trashObject4 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject4" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject4Geo .\n'
#  '\n'
#  'TRASH:trashObject5 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject5" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject5Geo .\n'
#  '\n'
#  'TRASH:trashObject6 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject6" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject6Geo .\n'
#  '\n'
#  'TRASH:trashObject7 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject7" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject7Geo .\n'
#  '\n'
#  'TRASH:trashObject8 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject8" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject8Geo .\n'
#  '\n'
#  'TRASH:trashObject9 a TRASH:PaperMaterial,\n'
#  '        owl:NamedIndividual ;\n'
#  '    rdfs:label "trashObject9" ;\n'
#  '    ns1:hasGeometry TRASH:trashObject9Geo .\n'
#  '\n'
#  'TRASH:trashObject10Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject10Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865752647309897 52.33413053095475)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject11Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject11Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865304699893835 52.334309552960946)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject12Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject12Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865281759264772 52.33398032492609)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject13Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject13Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865388905621926 52.33354589621061)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject14Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject14Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865369545486047 52.3341921760521)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject15Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject15Geo" ;\n'
#  '    ns1:asWKT "POINT (4.864840395614031 52.33412423144216)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject16Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject16Geo" ;\n'
#  '    ns1:asWKT "POINT (4.864967317533181 52.33351992894137)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject17Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject17Geo" ;\n'
#  '    ns1:asWKT "POINT (4.864833097519473 52.33421136067318)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject18Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject18Geo" ;\n'
#  '    ns1:asWKT "POINT (4.86578516572105 52.333947227249105)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject19Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject19Geo" ;\n'
#  '    ns1:asWKT "POINT (4.864823952055052 52.33370533872727)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject1Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject1Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865819303729258 52.3336155264158)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject20Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject20Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865020995475645 52.3337785054646)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject2Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject2Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865469798252866 52.33422422899857)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject3Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject3Geo" ;\n'
#  '    ns1:asWKT "POINT (4.8655078542820265 52.33365351824433)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject4Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject4Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865287451256917 52.33385553549447)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject5Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject5Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865810394776309 52.334056595618115)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject6Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject6Geo" ;\n'
#  '    ns1:asWKT "POINT (4.86554643904503 52.33420109713756)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject7Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject7Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865253270058119 52.33379446288854)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject8Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject8Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865825097146732 52.333703836702966)"^^ns1:wktLiteral '
#  '.\n'
#  '\n'
#  'TRASH:trashObject9Geo a ns1:Geometry ;\n'
#  '    rdfs:label "trashObject9Geo" ;\n'
#  '    ns1:asWKT "POINT (4.865454266364162 52.33416053928139)"^^ns1:wktLiteral '
#  '.\n'
#  '\n')

# %%
g_trash.serialize(destination="./data/trash_objects.ttl")
# Out:
# <Graph identifier=Nb536bc37057d480c91cac9a0d79325e1 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# # Add together

# %%
g_new = g + g_trash

# %%
g_new.add((TRASH.VURobot, RDF.type, "http://knowrob.org/kb/urdf.owl#Robot"))
g_new.add((TRASH.VURobot, RDFS.label, Literal("VURobot")))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11012/1681928739.py in <module>
# ----> 1 g_new.add((TRASH.VURobot, RDF.type, "http://knowrob.org/kb/urdf.owl#Robot"))
#       2 g_new.add((TRASH.VURobot, RDFS.label, Literal("VURobot")))
#
# ~\anaconda3\envs\geopandas\lib\site-packages\rdflib\graph.py in add(self, triple)
#     426         assert isinstance(s, Node), "Subject %s must be an rdflib term" % (s,)
#     427         assert isinstance(p, Node), "Predicate %s must be an rdflib term" % (p,)
# --> 428         assert isinstance(o, Node), "Object %s must be an rdflib term" % (o,)
#     429         self.__store.add((s, p, o), self, quoted=False)
#     430         return self
#
# AssertionError: Object http://knowrob.org/kb/urdf.owl#Robot must be an rdflib term

# %%
g_new.serialize(destination="./data/ontology.ttl")
